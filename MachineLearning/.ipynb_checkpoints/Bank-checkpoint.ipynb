# %% [markdown]
# # 金融機関のキャンペーン分析

# %%
import pandas as pd
import math
from sklearn import tree
from sklearn.model_selection import train_test_split
# %matplotlib inline
df = pd.read_csv("datafiles/Bank.csv")
df.head(3)
# Out:
#    id  age           job  marital  education default  amount housing loan  \
# 0   1   39   blue-collar  married  secondary      no  1756.0     yes   no
# 1   2   51  entrepreneur  married    primary      no  1443.0      no   no
# 2   3   36    management   single   tertiary      no   436.0      no   no
#
#     contact  day month    duration  campaign  previous  y
# 0  cellular    3   apr  370.055237         1         0  1
# 1  cellular   18   feb  233.998933        10         0  1
# 2  cellular   13   apr         NaN         1         2  0

# %%
# まず、ダミー変数化をしたいが、文字列の列が複数あるので抜き出す。
str_col_name=['job','default','marital','education','housing','loan','contact','month']
str_df = df[str_col_name]
#複数列を一気にダミー変数化
str_df2=pd.get_dummies(str_df,drop_first=True)

num_df = df.drop(str_col_name,axis=1)#数値列を抜き出す
df2 = pd.concat([num_df,str_df2,str_df],axis=1)#結合(今後の集計の利便性も考慮してstr_dfも結合しておく)

df2
# Out:
#           id  age  amount  day    duration  campaign  previous  y  \
# 0          1   39  1756.0    3  370.055237         1         0  1
# 1          2   51  1443.0   18  233.998933        10         0  1
# 2          3   36   436.0   13         NaN         1         2  0
# 3          4   63   474.0   25  252.525808         1         0  0
# 4          5   31   354.0   30         NaN         1         2  0
# ...      ...  ...     ...  ...         ...       ...       ... ..
# 27123  27124   42  1455.0    2  246.943522         2         2  0
# 27124  27125   34   719.0   15         NaN         3         0  1
# 27125  27126   36    49.0    8  303.008360         1         0  0
# 27126  27127   33   209.0   12  258.334424         4         0  1
# 27127  27128   29    40.0   18  321.215556         1         2  0
#
#        job_blue-collar  job_entrepreneur  ...  month_oct  month_sep  \
# 0                    1                 0  ...          0          0
# 1                    0                 1  ...          0          0
# 2                    0                 0  ...          0          0
# 3                    0                 0  ...          0          0
# 4                    0                 0  ...          0          0
# ...                ...               ...  ...        ...        ...
# 27123                1                 0  ...          0          0
# 27124                0                 0  ...          0          0
# 27125                1                 0  ...          0          0
# 27126                0                 0  ...          0          0
# 27127                0                 0  ...          0          0
#
#                 job  default  marital  education  housing  loan  \
# 0       blue-collar       no  married  secondary      yes    no
# 1      entrepreneur       no  married    primary       no    no
# 2        management       no   single   tertiary       no    no
# 3           retired       no  married  secondary       no    no
# 4        management       no   single   tertiary       no    no
# ...             ...      ...      ...        ...      ...   ...
# 27123   blue-collar       no  married    primary      yes    no
# 27124      services       no   single  secondary      yes    no
# 27125   blue-collar       no   single    primary      yes    no
# 27126     housemaid       no  married    primary       no    no
# 27127      services       no   single  secondary      yes    no
#
#                  contact  month
# 0               cellular    apr
# 1               cellular    feb
# 2               cellular    apr
# 3               cellular    jan
# 4               cellular    apr
# ...                  ...    ...
# 27123           cellular    feb
# 27124  sending _document    may
# 27125  sending _document    may
# 27126           cellular    aug
# 27127           cellular    may
#
# [27128 rows x 48 columns]

# %%
#訓練&検証データとテストデータに分割
train_val,test = train_test_split(df2,test_size=0.1,random_state=9)
train_val.head()
# Out:
#           id  age  amount  day    duration  campaign  previous  y  \
# 13378  13379   46     0.0   10  378.293875         1         0  1
# 3800    3801   41  -333.0   30  300.845752         3         2  0
# 10398  10399   30  5389.0    6  159.053623         3         0  1
# 23401  23402   39   255.0    5  334.802583         1         0  0
# 26223  26224   47    33.0    5         NaN         1         0  1
#
#        job_blue-collar  job_entrepreneur  ...  month_oct  month_sep  \
# 13378                0                 0  ...          0          0
# 3800                 1                 0  ...          0          0
# 10398                0                 0  ...          0          0
# 23401                0                 0  ...          0          0
# 26223                0                 0  ...          0          0
#
#                job  default   marital  education  housing  loan  \
# 13378   unemployed       no   married   tertiary      yes    no
# 3800   blue-collar       no  divorced  secondary      yes    no
# 10398   management       no    single   tertiary       no    no
# 23401   management       no    single   tertiary      yes    no
# 26223     services       no    single  secondary      yes    no
#
#                  contact  month
# 13378           cellular    jul
# 3800            cellular    jan
# 10398           cellular    aug
# 23401  sending _document    may
# 26223           cellular    may
#
# [5 rows x 48 columns]

# %% [markdown]
# #欠損値の確認

# %%
a=train_val.isnull().sum()
a[a>0]
# Out:
# duration    6331
# dtype: int64

# %%
#中央値で補完
train_val['duration'].median()
train_val2= train_val.fillna(train_val.median())
# Out:
# C:\Users\msy-t\AppData\Local\Temp\ipykernel_17116\1551038528.py:3: FutureWarning: The default value of numeric_only in DataFrame.median is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   train_val2= train_val.fillna(train_val.median())

# %%
#不均衡なデータであるか確認
train_val2['y'].value_counts()
# Out:
# 0    16601
# 1     7814
# Name: y, dtype: int64

# %%
t =train_val2['y']
x = train_val2.drop(str_col_name,axis=1)
x =x.drop(['id','y','day'],axis=1)

model = tree.DecisionTreeClassifier(random_state=3,max_depth=3,class_weight='balanced')

def learn(x,t,i):
    x_train,x_val,y_train,y_val = train_test_split(x,t,test_size=0.2,random_state=13)

    datas=[x_train,x_val,y_train,y_val]
    #不均衡データに対応できるように、class_weight引数も設定
    model = tree.DecisionTreeClassifier(random_state=i,max_depth=i,class_weight='balanced')
    model.fit(x_train,y_train)
    train_score=model.score(x_train,y_train)
    
    val_score=model.score(x_val,y_val)
    return train_score,val_score,model,datas

# %%
for i in range(1,20):
    s1,s2,model,datas = learn(x,t,i)
    print(i,s1,s2)
# Out:
# 1 0.6995187384804423 0.6993651443784559
# 2 0.6492422690968667 0.6493958631988531
# 3 0.6492422690968667 0.6493958631988531
# 4 0.7357669465492525 0.7481056727421667
# 5 0.7767765717796437 0.7773909481875896
# 6 0.80124923202949 0.8023755887773909
# 7 0.8224452181036248 0.8095433135367602
# 8 0.8448699569936514 0.8238787630554987
# 9 0.858386237968462 0.8230595945115707
# 10 0.8756399754249437 0.829817734998976
# 11 0.8987814867909072 0.8363710833503993
# 12 0.910147450337907 0.8269506450952283
# 13 0.9284251484742986 0.8236739709195167
# 14 0.943170182265001 0.8124104034405079
# 15 0.9587343845996313 0.820397296743805
# 16 0.9684620110587754 0.8156870776162195
# 17 0.9776264591439688 0.8177349989760393
# 18 0.9845893917673562 0.8134343641204178
# 19 0.9900163833708786 0.8152774933442556

# %%
#深さ11以降はvalが停滞するので過学習が発生ここでテストデータでチェック
model = tree.DecisionTreeClassifier(max_depth=11,random_state=11)
model.fit(x,t)
test2 = test.copy()
test2=test2.fillna(train_val.median())

test_y=test2['y']
test_x = test2.drop(str_col_name,axis=1)
test_x =test_x.drop(['id','y','day'],axis=1)
model.score(test_x,test_y)
# Out:
# C:\Users\msy-t\AppData\Local\Temp\ipykernel_17116\1897981322.py:5: FutureWarning: The default value of numeric_only in DataFrame.median is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   test2=test2.fillna(train_val.median())
# 0.8330261702911905

# %%
#特徴量重要度の確認(ちなみに、連続量とダミー変数を比べると、連続量の方が重要度は高め出力されてしまう事に注意)
a=pd.Series(model.feature_importances_,index=x.columns).sort_values(ascending=False)
a[a>0.01]#campaignやdurationが重要度が大きいと分かる
# Out:
# duration                     0.529793
# age                          0.143316
# campaign                     0.103042
# housing_yes                  0.064951
# loan_yes                     0.041739
# amount                       0.039681
# previous                     0.015744
# contact_sending _document    0.014536
# dtype: float64

# %% [markdown]
# #durationの欠損値処理

# %%
str_df.columns
# Out:
# Index(['job', 'default', 'marital', 'education', 'housing', 'loan', 'contact',
#        'month'],
#       dtype='object')

# %%
for name in str_df.columns:
    print(train_val.groupby(name)['y'].mean())
    print('=============')
# Out:
# job
# admin.           0.304550
# blue-collar      0.352886
# entrepreneur     0.390453
# housemaid        0.290043
# management       0.307299
# retired          0.369268
# self-employed    0.301974
# services         0.337611
# student          0.166667
# technician       0.307423
# unemployed       0.241084
# unknown          0.294118
# Name: y, dtype: float64
# =============
# default
# no     0.321336
# yes    0.249428
# Name: y, dtype: float64
# =============
# marital
# divorced    0.334059
# married     0.341211
# single      0.269086
# Name: y, dtype: float64
# =============
# education
# primary      0.351921
# secondary    0.318327
# tertiary     0.301592
# unknown      0.354354
# Name: y, dtype: float64
# =============
# housing
# no     0.217959
# yes    0.400910
# Name: y, dtype: float64
# =============
# loan
# no     0.300195
# yes    0.424328
# Name: y, dtype: float64
# =============
# contact
# cellular             0.277883
# sending _document    0.416372
# telephone            0.311842
# Name: y, dtype: float64
# =============
# month
# apr    0.312070
# aug    0.251950
# dec    0.327731
# feb    0.266805
# jan    0.202073
# jul    0.307506
# jun    0.356744
# mar    0.354244
# may    0.389833
# nov    0.234457
# oct    0.308483
# sep    0.327217
# Name: y, dtype: float64
# =============

# %%
#housing,loan,contactが関係あり
print(pd.pivot_table(train_val,index="housing",columns="loan",values="duration"))
print(pd.pivot_table(train_val,index="housing",columns="contact",values="duration"))
print(pd.pivot_table(train_val,index="loan",columns="contact",values="duration"))
# Out:
# loan             no         yes
# housing
# no       237.256887  301.180261
# yes      332.635840  439.472217
# contact    cellular  sending _document   telephone
# housing
# no       249.821962         249.179202  272.785529
# yes      348.532350         349.179816  368.638141
# contact    cellular  sending _document   telephone
# loan
# no       297.588613         314.969378  304.960446
# yes      375.465455         400.911698  379.000771

# %%
#今回は、loan×housingで対応
def nan_fill(train_val):
    isnull = train_val['duration'].isnull()

    #train_valを変えたくないので、py基本文法のcopyメソッドでコピーを作って
    #train_val2に代入
    train_val2 = train_val.copy()
    #housing=yesの処理
    train_val2.loc[(isnull) & (train_val2['housing']=='yes') 
                  &(train_val2['loan']=='yes'),'duration' ]=439
    train_val2.loc[(isnull) & (train_val2['housing']=='yes') 
                  &(train_val2['loan']=='no'),'duration' ]=332

    #housing=noの処理
    train_val2.loc[(isnull) & (train_val2['housing']=='no') 
                  &(train_val2['loan']=='yes'),'duration' ]=301
    train_val2.loc[(isnull) & (train_val2['housing']=='no') 
                  &(train_val2['loan']=='no'),'duration' ]=237
    
    return train_val2
train_val2=nan_fill(train_val)

# %%
train_val2.groupby('y')['duration'].mean()#durationが長いほうが、y=1になる可能性が高い
# Out:
# y
# 0    283.188078
# 1    350.596458
# Name: duration, dtype: float64

# %%
#ここでいったん、learn関数で分析
t =train_val2['y']

x = train_val2.drop(str_col_name,axis=1)
x =x.drop(['id','y','day'],axis=1)
#x =train_val2[xcol]
for i in range(1,20):
    s1,s2,model,datas = learn(x,t,i)
    print(i,s1,s2)
# Out:
# 1 0.7462113454843334 0.7511775547818964
# 2 0.7462113454843334 0.7511775547818964
# 3 0.7507167724759369 0.7554781896375179
# 4 0.7481056727421667 0.7569117345893918
# 5 0.7746262543518329 0.7751382346917879
# 6 0.7780565226295311 0.7712471841081302
# 7 0.8182469793159942 0.8117960270325619
# 8 0.8275138234691788 0.8077001843129223
# 9 0.8483514233053451 0.8273602293671923
# 10 0.8692402211755068 0.8335039934466516
# 11 0.8782510751587139 0.8251075158713905
# 12 0.8999590415728036 0.8261314765513005
# 13 0.914294491091542 0.8281793979111202
# 14 0.9298074953921769 0.8220356338316609
# 15 0.9457812819987712 0.8220356338316609
# 16 0.9606287118574647 0.820602088879787
# 17 0.9706123284865861 0.8171206225680934
# 18 0.9785992217898832 0.8187589596559492
# 19 0.9862277288552119 0.8199877124718411

# %%
#どのような間違い方をしているのか確認
s1,s2,model,datas = learn(x,t,10)

#訓練データでの予測結果と実際の値の2軸で個数集計flagがFalseならば、検証データで集計
def syuukei(model,datas,flag=False):
    if flag:
        pre=model.predict(datas[0])
        y_val=datas[2]
    else:
        pre=model.predict(datas[1])
        y_val=datas[3]
    data={
        "pred":pre,
        "true":y_val
    }
    tmp=pd.DataFrame(data)
    return tmp,pd.pivot_table(tmp,index="true",columns="pred",values="true",aggfunc=len)
tmp,a=syuukei(model,datas,False)
a
# Out:
# pred     0     1
# true
# 0     2796   587
# 1      226  1274

# %%
#本当はｙ＝０の中で、正確に予測された人と謝った予測をされた人でどういう傾向があるか分析

false=tmp.loc[(tmp['pred']==1)&(tmp['true']==0)].index
true=tmp.loc[(tmp['pred']==0)&(tmp['true']==0)].index
true_df=train_val2.loc[true]
false_df=train_val2.loc[false]
pd.concat([true_df.mean()["age":],false_df.mean()["age":]],axis=1).plot(kind="bar")
true
# Out:
# C:\Users\msy-t\AppData\Local\Temp\ipykernel_17116\832376104.py:7: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   pd.concat([true_df.mean()["age":],false_df.mean()["age":]],axis=1).plot(kind="bar")
# C:\Users\msy-t\AppData\Local\Temp\ipykernel_17116\832376104.py:7: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   pd.concat([true_df.mean()["age":],false_df.mean()["age":]],axis=1).plot(kind="bar")
# Int64Index([ 8008,  5734,  1594,  2167, 10468, 26200,  7851,  4695, 24120,
#             18766,
#             ...
#             14655,  5003,  4196, 17968, 13960,  1548,   508,  7200,  9861,
#             20515],
#            dtype='int64', length=2796)

# %%
#値にばらつきが大きいので、標準化してもう一度グラフ化
from sklearn.preprocessing import StandardScaler

sc = StandardScaler()
tmp2=train_val2.drop(str_col_name,axis=1)
sc_data = sc.fit_transform(tmp2)
sc_df = pd.DataFrame(sc_data,columns=tmp2.columns,index=tmp2.index)

true_df=sc_df.loc[true]
false_df=sc_df.loc[false]
true_df
temp2=pd.concat([false_df.mean()["age":],true_df.mean()["age":]],axis=1)
temp2.plot(kind="bar")
# Out:
# <Axes: >

# %% [markdown]
# #青色の０は誤分類、オレンジ１は正解のデータ
#
# #durationと housing_yesが大きく異なる\
# #実際はy=0の人で、 durationが大きい人は誤分類しやすい\
# #実際はy=0の人で、 housingが大きい人は誤分類しやすい
#
#
# #事前に、durationが大きい人はy=1になりやすいということは分かっているので、「こういう人はy=0になりやすい」という\
# #特徴量を見つけ出して、特徴量×durationという特徴量を作って、durationに重み付けをする列を作れば正解率があがるのではないか？

# %%
model_tree=tree.DecisionTreeClassifier(max_depth=10,random_state=10,class_weight="balanced")
model_tree.fit(x,t)

test2=nan_fill(test)
t =test2['y']
x = test2.drop(str_col_name,axis=1)
x =x.drop(['id','y','day'],axis=1)
model_tree.score(x,t)
# Out:
# 0.815333579063767

# %%
from sklearn.tree import plot_tree
# plot_tree関数で決定木を描画
plot_tree(model, feature_names = x.columns.tolist(),filled = True)
# Out:
# [Text(0.5040447356356969, 0.9545454545454546, 'duration <= 325.355\ngini = 0.5\nsamples = 19532\nvalue = [9766.0, 9766.0]'),
#  Text(0.2411560207823961, 0.8636363636363636, 'campaign <= 2.5\ngini = 0.398\nsamples = 11889\nvalue = [7443.823, 2805.753]'),
#  Text(0.12274602689486552, 0.7727272727272727, 'duration <= 213.731\ngini = 0.258\nsamples = 8121\nvalue = [5525.792, 992.995]'),
#  Text(0.04851772616136919, 0.6818181818181818, 'duration <= 148.575\ngini = 0.495\nsamples = 510\nvalue = [237.907, 290.784]'),
#  Text(0.022692542787286062, 0.5909090909090909, 'age <= 29.5\ngini = 0.396\nsamples = 185\nvalue = [115.998, 43.308]'),
#  Text(0.01115525672371638, 0.5, 'duration <= 107.802\ngini = 0.492\nsamples = 74\nvalue = [39.897, 30.934]'),
#  Text(0.003667481662591687, 0.4090909090909091, 'previous <= 3.5\ngini = 0.313\nsamples = 29\nvalue = [19.21, 4.64]'),
#  Text(0.0024449877750611247, 0.3181818181818182, 'job_management <= 0.5\ngini = 0.239\nsamples = 28\nvalue = [19.21, 3.093]'),
#  Text(0.0012224938875305623, 0.22727272727272727, 'gini = 0.0\nsamples = 23\nvalue = [16.993, 0.0]'),
#  Text(0.003667481662591687, 0.22727272727272727, 'duration <= 93.039\ngini = 0.486\nsamples = 5\nvalue = [2.217, 3.093]'),
#  Text(0.0024449877750611247, 0.13636363636363635, 'gini = 0.0\nsamples = 2\nvalue = [0.0, 3.093]'),
#  Text(0.004889975550122249, 0.13636363636363635, 'month_mar <= 0.5\ngini = 0.0\nsamples = 3\nvalue = [2.217, 0.0]'),
#  Text(0.003667481662591687, 0.045454545454545456, 'gini = 0.0\nsamples = 2\nvalue = [1.478, 0.0]'),
#  Text(0.006112469437652812, 0.045454545454545456, 'gini = 0.0\nsamples = 1\nvalue = [0.739, 0.0]'),
#  Text(0.004889975550122249, 0.3181818181818182, 'gini = -0.0\nsamples = 1\nvalue = [0.0, 1.547]'),
#  Text(0.018643031784841075, 0.4090909090909091, 'amount <= 2168.0\ngini = 0.493\nsamples = 45\nvalue = [20.688, 26.294]'),
#  Text(0.015281173594132029, 0.3181818181818182, 'contact_telephone <= 0.5\ngini = 0.461\nsamples = 37\nvalue = [14.777, 26.294]'),
#  Text(0.012224938875305624, 0.22727272727272727, 'month_jul <= 0.5\ngini = 0.446\nsamples = 35\nvalue = [13.299, 26.294]'),
#  Text(0.009779951100244499, 0.13636363636363635, 'previous <= 2.5\ngini = 0.4\nsamples = 27\nvalue = [8.866, 23.201]'),
#  Text(0.008557457212713936, 0.045454545454545456, 'gini = 0.366\nsamples = 25\nvalue = [7.388, 23.201]'),
#  Text(0.011002444987775062, 0.045454545454545456, 'gini = -0.0\nsamples = 2\nvalue = [1.478, 0.0]'),
#  Text(0.014669926650366748, 0.13636363636363635, 'age <= 28.5\ngini = 0.484\nsamples = 8\nvalue = [4.433, 3.093]'),
#  Text(0.013447432762836185, 0.045454545454545456, 'gini = 0.0\nsamples = 4\nvalue = [2.955, 0.0]'),
#  Text(0.01589242053789731, 0.045454545454545456, 'gini = 0.438\nsamples = 4\nvalue = [1.478, 3.093]'),
#  Text(0.018337408312958436, 0.22727272727272727, 'month_feb <= 0.5\ngini = 0.0\nsamples = 2\nvalue = [1.478, 0.0]'),
#  Text(0.017114914425427872, 0.13636363636363635, 'gini = 0.0\nsamples = 1\nvalue = [0.739, 0.0]'),
#  Text(0.019559902200488997, 0.13636363636363635, 'gini = 0.0\nsamples = 1\nvalue = [0.739, 0.0]'),
#  Text(0.022004889975550123, 0.3181818181818182, 'education_secondary <= 0.5\ngini = 0.0\nsamples = 8\nvalue = [5.911, 0.0]'),
#  Text(0.02078239608801956, 0.22727272727272727, 'gini = 0.0\nsamples = 5\nvalue = [3.694, 0.0]'),
#  Text(0.023227383863080684, 0.22727272727272727, 'gini = 0.0\nsamples = 3\nvalue = [2.217, 0.0]'),
#  Text(0.034229828850855744, 0.5, 'contact_sending _document <= 0.5\ngini = 0.241\nsamples = 111\nvalue = [76.101, 12.374]'),
#  Text(0.029339853300733496, 0.4090909090909091, 'amount <= 2.5\ngini = 0.122\nsamples = 93\nvalue = [66.496, 4.64]'),
#  Text(0.02689486552567237, 0.3181818181818182, 'job_entrepreneur <= 0.5\ngini = 0.384\nsamples = 14\nvalue = [8.866, 3.093]'),
#  Text(0.02567237163814181, 0.22727272727272727, 'duration <= 130.07\ngini = 0.253\nsamples = 13\nvalue = [8.866, 1.547]'),
#  Text(0.02444987775061125, 0.13636363636363635, 'gini = 0.0\nsamples = 9\nvalue = [6.65, 0.0]'),
#  Text(0.02689486552567237, 0.13636363636363635, 'duration <= 137.963\ngini = 0.484\nsamples = 4\nvalue = [2.217, 1.547]'),
#  Text(0.02567237163814181, 0.045454545454545456, 'gini = 0.0\nsamples = 1\nvalue = [0.0, 1.547]'),
#  Text(0.028117359413202935, 0.045454545454545456, 'gini = 0.0\nsamples = 3\nvalue = [2.217, 0.0]'),
#  Text(0.028117359413202935, 0.22727272727272727, 'gini = 0.0\nsamples = 1\nvalue = [0.0, 1.547]'),
#  Text(0.03178484107579462, 0.3181818181818182, 'job_unemployed <= 0.5\ngini = 0.051\nsamples = 79\nvalue = [57.63, 1.547]'),
#  Text(0.030562347188264057, 0.22727272727272727, 'gini = 0.0\nsamples = 72\nvalue = [53.197, 0.0]'),
#  Text(0.03300733496332518, 0.22727272727272727, 'duration <= 142.143\ngini = 0.384\nsamples = 7\nvalue = [4.433, 1.547]'),
#  Text(0.03178484107579462, 0.13636363636363635, 'education_tertiary <= 0.5\ngini = 0.0\nsamples = 6\nvalue = [4.433, 0.0]'),
#  Text(0.030562347188264057, 0.045454545454545456, 'gini = 0.0\nsamples = 3\nvalue = [2.217, 0.0]'),
#  Text(0.03300733496332518, 0.045454545454545456, 'gini = 0.0\nsamples = 3\nvalue = [2.217, 0.0]'),
#  Text(0.034229828850855744, 0.13636363636363635, 'gini = -0.0\nsamples = 1\nvalue = [0.0, 1.547]'),
#  Text(0.039119804400977995, 0.4090909090909091, 'education_tertiary <= 0.5\ngini = 0.494\nsamples = 18\nvalue = [9.605, 7.734]'),
#  Text(0.03667481662591687, 0.3181818181818182, 'month_feb <= 0.5\ngini = 0.286\nsamples = 11\nvalue = [7.388, 1.547]'),
#  Text(0.035452322738386305, 0.22727272727272727, 'gini = -0.0\nsamples = 10\nvalue = [7.388, 0.0]'),
#  Text(0.037897310513447434, 0.22727272727272727, 'gini = 0.0\nsamples = 1\nvalue = [0.0, 1.547]'),
#  Text(0.04156479217603912, 0.3181818181818182, 'duration <= 136.039\ngini = 0.388\nsamples = 7\nvalue = [2.217, 6.187]'),
#  Text(0.040342298288508556, 0.22727272727272727, 'amount <= 1014.0\ngini = 0.191\nsamples = 5\nvalue = [0.739, 6.187]'),
#  Text(0.039119804400977995, 0.13636363636363635, 'gini = 0.0\nsamples = 3\nvalue = [0.0, 4.64]'),
#  Text(0.04156479217603912, 0.13636363636363635, 'month_may <= 0.5\ngini = 0.438\nsamples = 2\nvalue = [0.739, 1.547]'),
#  Text(0.040342298288508556, 0.045454545454545456, 'gini = 0.0\nsamples = 1\nvalue = [0.739, 0.0]'),
#  Text(0.042787286063569685, 0.045454545454545456, 'gini = 0.0\nsamples = 1\nvalue = [0.0, 1.547]'),
#  Text(0.042787286063569685, 0.22727272727272727, 'gini = 0.0\nsamples = 2\nvalue = [1.478, 0.0]'),
#  Text(0.07434290953545232, 0.5909090909090909, 'age <= 41.5\ngini = 0.442\nsamples = 325\nvalue = [121.909, 247.475]'),
#  Text(0.058985330073349634, 0.5, 'loan_yes <= 0.5\ngini = 0.37\nsamples = 230\nvalue = [68.712, 211.901]'),
#  Text(0.05776283618581907, 0.4090909090909091, 'month_aug <= 0.5\ngini = 0.343\nsamples = 218\nvalue = [59.846, 211.901]'),
#  Text(0.053178484107579464, 0.3181818181818182, 'duration <= 164.664\ngini = 0.307\nsamples = 189\nvalue = [45.808, 196.434]'),
#  Text(0.0488997555012225, 0.22727272727272727, 'previous <= 1.5\ngini = 0.45\nsamples = 48\nvalue = [18.471, 35.575]'),
#  Text(0.04645476772616137, 0.13636363636363635, 'job_technician <= 0.5\ngini = 0.379\nsamples = 36\nvalue = [11.083, 32.481]'),
#  Text(0.04523227383863081, 0.045454545454545456, 'gini = 0.468\nsamples = 27\nvalue = [11.083, 18.561]'),
#  Text(0.04767726161369193, 0.045454545454545456, 'gini = 0.0\nsamples = 9\nvalue = [0.0, 13.92]'),
#  Text(0.05134474327628362, 0.13636363636363635, 'month_jul <= 0.5\ngini = 0.416\nsamples = 12\nvalue = [7.388, 3.093]'),
#  Text(0.05012224938875306, 0.045454545454545456, 'gini = 0.286\nsamples = 11\nvalue = [7.388, 1.547]'),
#  Text(0.05256723716381418, 0.045454545454545456, 'gini = 0.0\nsamples = 1\nvalue = [0.0, 1.547]'),
#  Text(0.05745721271393643, 0.22727272727272727, 'housing_yes <= 0.5\ngini = 0.248\nsamples = 141\nvalue = [27.337, 160.859]'),
#  Text(0.05623471882640587, 0.13636363636363635, 'age <= 36.5\ngini = 0.234\nsamples = 138\nvalue = [25.121, 160.859]'),
#  Text(0.0550122249388753, 0.045454545454545456, 'gini = 0.156\nsamples = 98\nvalue = [11.821, 126.831]'),
#  Text(0.05745721271393643, 0.045454545454545456, 'gini = 0.404\nsamples = 40\nvalue = [13.299, 34.028]'),
#  Text(0.05867970660146699, 0.13636363636363635, 'gini = -0.0\nsamples = 3\nvalue = [2.217, 0.0]'),
#  Text(0.06234718826405868, 0.3181818181818182, 'duration <= 154.81\ngini = 0.499\nsamples = 29\nvalue = [14.038, 15.467]'),
#  Text(0.061124694376528114, 0.22727272727272727, 'gini = 0.0\nsamples = 2\nvalue = [0.0, 3.093]'),
#  Text(0.06356968215158924, 0.22727272727272727, 'education_secondary <= 0.5\ngini = 0.498\nsamples = 27\nvalue = [14.038, 12.374]'),
#  Text(0.061124694376528114, 0.13636363636363635, 'duration <= 199.109\ngini = 0.482\nsamples = 17\nvalue = [7.388, 10.827]'),
#  Text(0.05990220048899755, 0.045454545454545456, 'gini = 0.5\nsamples = 15\nvalue = [7.388, 7.734]'),
#  Text(0.06234718826405868, 0.045454545454545456, 'gini = -0.0\nsamples = 2\nvalue = [0.0, 3.093]'),
#  Text(0.06601466992665037, 0.13636363636363635, 'age <= 32.0\ngini = 0.306\nsamples = 10\nvalue = [6.65, 1.547]'),
#  Text(0.0647921760391198, 0.045454545454545456, 'gini = 0.0\nsamples = 1\nvalue = [0.0, 1.547]'),
#  Text(0.06723716381418093, 0.045454545454545456, 'gini = -0.0\nsamples = 9\nvalue = [6.65, 0.0]'),
#  Text(0.060207823960880195, 0.4090909090909091, 'gini = -0.0\nsamples = 12\nvalue = [8.866, 0.0]'),
#  Text(0.089700488997555, 0.5, 'contact_sending _document <= 0.5\ngini = 0.48\nsamples = 95\nvalue = [53.197, 35.575]'),
#  Text(0.08160146699266503, 0.4090909090909091, 'amount <= 3544.0\ngini = 0.256\nsamples = 64\nvalue = [43.592, 7.734]'),
#  Text(0.0776283618581907, 0.3181818181818182, 'job_unemployed <= 0.5\ngini = 0.187\nsamples = 57\nvalue = [39.897, 4.64]'),
#  Text(0.07334963325183375, 0.22727272727272727, 'duration <= 211.636\ngini = 0.079\nsamples = 50\nvalue = [36.203, 1.547]'),
#  Text(0.07090464547677261, 0.13636363636363635, 'job_management <= 0.5\ngini = 0.0\nsamples = 46\nvalue = [33.987, 0.0]'),
#  Text(0.06968215158924206, 0.045454545454545456, 'gini = 0.0\nsamples = 32\nvalue = [23.643, 0.0]'),
#  Text(0.07212713936430318, 0.045454545454545456, 'gini = 0.0\nsamples = 14\nvalue = [10.344, 0.0]'),
#  Text(0.07579462102689487, 0.13636363636363635, 'duration <= 212.872\ngini = 0.484\nsamples = 4\nvalue = [2.217, 1.547]'),
#  Text(0.0745721271393643, 0.045454545454545456, 'gini = 0.0\nsamples = 1\nvalue = [0.0, 1.547]'),
#  Text(0.07701711491442542, 0.045454545454545456, 'gini = 0.0\nsamples = 3\nvalue = [2.217, 0.0]'),
#  Text(0.08190709046454768, 0.22727272727272727, 'campaign <= 1.5\ngini = 0.496\nsamples = 7\nvalue = [3.694, 3.093]'),
#  Text(0.08068459657701711, 0.13636363636363635, 'age <= 42.5\ngini = 0.438\nsamples = 4\nvalue = [1.478, 3.093]'),
#  Text(0.07946210268948656, 0.045454545454545456, 'gini = 0.0\nsamples = 1\nvalue = [0.739, 0.0]'),
#  Text(0.08190709046454768, 0.045454545454545456, 'gini = 0.311\nsamples = 3\nvalue = [0.739, 3.093]'),
#  Text(0.08312958435207823, 0.13636363636363635, 'gini = 0.0\nsamples = 3\nvalue = [2.217, 0.0]'),
#  Text(0.08557457212713937, 0.3181818181818182, 'age <= 46.5\ngini = 0.496\nsamples = 7\nvalue = [3.694, 3.093]'),
#  Text(0.0843520782396088, 0.22727272727272727, 'gini = 0.0\nsamples = 3\nvalue = [2.217, 0.0]'),
#  Text(0.08679706601466992, 0.22727272727272727, 'duration <= 183.016\ngini = 0.438\nsamples = 4\nvalue = [1.478, 3.093]'),
#  Text(0.08557457212713937, 0.13636363636363635, 'gini = 0.0\nsamples = 1\nvalue = [0.739, 0.0]'),
#  Text(0.08801955990220049, 0.13636363636363635, 'duration <= 209.044\ngini = 0.311\nsamples = 3\nvalue = [0.739, 3.093]'),
#  Text(0.08679706601466992, 0.045454545454545456, 'gini = 0.0\nsamples = 2\nvalue = [0.0, 3.093]'),
#  Text(0.08924205378973105, 0.045454545454545456, 'gini = 0.0\nsamples = 1\nvalue = [0.739, 0.0]'),
#  Text(0.097799511002445, 0.4090909090909091, 'month_may <= 0.5\ngini = 0.381\nsamples = 31\nvalue = [9.605, 27.841]'),
#  Text(0.09535452322738386, 0.3181818181818182, 'job_housemaid <= 0.5\ngini = 0.461\nsamples = 24\nvalue = [9.605, 17.014]'),
#  Text(0.0941320293398533, 0.22727272727272727, 'campaign <= 1.5\ngini = 0.492\nsamples = 21\nvalue = [9.605, 12.374]'),
#  Text(0.09290953545232274, 0.13636363636363635, 'age <= 46.5\ngini = 0.455\nsamples = 17\nvalue = [6.65, 12.374]'),
#  Text(0.09168704156479218, 0.045454545454545456, 'gini = 0.311\nsamples = 9\nvalue = [2.217, 9.28]'),
#  Text(0.0941320293398533, 0.045454545454545456, 'gini = 0.484\nsamples = 8\nvalue = [4.433, 3.093]'),
#  Text(0.09535452322738386, 0.13636363636363635, 'gini = -0.0\nsamples = 4\nvalue = [2.955, 0.0]'),
#  Text(0.09657701711491443, 0.22727272727272727, 'gini = -0.0\nsamples = 3\nvalue = [0.0, 4.64]'),
#  Text(0.10024449877750612, 0.3181818181818182, 'amount <= -650.0\ngini = 0.0\nsamples = 7\nvalue = [0.0, 10.827]'),
#  Text(0.09902200488997555, 0.22727272727272727, 'gini = 0.0\nsamples = 1\nvalue = [0.0, 1.547]'),
#  Text(0.10146699266503667, 0.22727272727272727, 'gini = 0.0\nsamples = 6\nvalue = [0.0, 9.28]'),
#  Text(0.19697432762836187, 0.6818181818181818, 'contact_sending _document <= 0.5\ngini = 0.207\nsamples = 7611\nvalue = [5287.885, 702.212]'),
#  Text(0.15869498777506114, 0.5909090909090909, 'age <= 61.5\ngini = 0.14\nsamples = 5725\nvalue = [4070.275, 334.092]'),
#  Text(0.132640586797066, 0.5, 'duration <= 248.023\ngini = 0.108\nsamples = 5515\nvalue = [3960.188, 239.742]'),
#  Text(0.11491442542787286, 0.4090909090909091, 'duration <= 236.696\ngini = 0.048\nsamples = 3164\nvalue = [2309.617, 58.775]'),
#  Text(0.10819070904645477, 0.3181818181818182, 'previous <= 4.5\ngini = 0.163\nsamples = 603\nvalue = [425.572, 41.761]'),
#  Text(0.1039119804400978, 0.22727272727272727, 'month_sep <= 0.5\ngini = 0.135\nsamples = 581\nvalue = [413.751, 32.481]'),
#  Text(0.10146699266503667, 0.13636363636363635, 'month_jun <= 0.5\ngini = 0.119\nsamples = 572\nvalue = [409.318, 27.841]'),
#  Text(0.10024449877750612, 0.045454545454545456, 'gini = 0.098\nsamples = 551\nvalue = [396.758, 21.654]'),
#  Text(0.10268948655256724, 0.045454545454545456, 'gini = 0.442\nsamples = 21\nvalue = [12.56, 6.187]'),
#  Text(0.10635696821515893, 0.13636363636363635, 'campaign <= 1.5\ngini = 0.5\nsamples = 9\nvalue = [4.433, 4.64]'),
#  Text(0.10513447432762836, 0.045454545454545456, 'gini = 0.366\nsamples = 5\nvalue = [1.478, 4.64]'),
#  Text(0.10757946210268948, 0.045454545454545456, 'gini = 0.0\nsamples = 4\nvalue = [2.955, 0.0]'),
#  Text(0.11246943765281174, 0.22727272727272727, 'age <= 39.5\ngini = 0.493\nsamples = 22\nvalue = [11.821, 9.28]'),
#  Text(0.11124694376528117, 0.13636363636363635, 'previous <= 10.5\ngini = 0.486\nsamples = 15\nvalue = [6.65, 9.28]'),
#  Text(0.1100244498777506, 0.045454545454545456, 'gini = 0.366\nsamples = 10\nvalue = [2.955, 9.28]'),
#  Text(0.11246943765281174, 0.045454545454545456, 'gini = 0.0\nsamples = 5\nvalue = [3.694, 0.0]'),
#  Text(0.1136919315403423, 0.13636363636363635, 'gini = -0.0\nsamples = 7\nvalue = [5.172, 0.0]'),
#  Text(0.12163814180929096, 0.3181818181818182, 'age <= 59.5\ngini = 0.018\nsamples = 2561\nvalue = [1884.044, 17.014]'),
#  Text(0.11735941320293398, 0.22727272727272727, 'duration <= 237.552\ngini = 0.013\nsamples = 2537\nvalue = [1868.529, 12.374]'),
#  Text(0.11613691931540342, 0.13636363636363635, 'gini = 0.0\nsamples = 2270\nvalue = [1677.169, 0.0]'),
#  Text(0.11858190709046455, 0.13636363636363635, 'duration <= 237.565\ngini = 0.114\nsamples = 267\nvalue = [191.36, 12.374]'),
#  Text(0.11735941320293398, 0.045454545454545456, 'gini = 0.0\nsamples = 1\nvalue = [0.0, 1.547]'),
#  Text(0.1198044009779951, 0.045454545454545456, 'gini = 0.101\nsamples = 266\nvalue = [191.36, 10.827]'),
#  Text(0.12591687041564792, 0.22727272727272727, 'education_tertiary <= 0.5\ngini = 0.354\nsamples = 24\nvalue = [15.516, 4.64]'),
#  Text(0.1234718826405868, 0.13636363636363635, 'job_management <= 0.5\ngini = 0.179\nsamples = 20\nvalue = [14.038, 1.547]'),
#  Text(0.12224938875305623, 0.045454545454545456, 'gini = 0.0\nsamples = 18\nvalue = [13.299, 0.0]'),
#  Text(0.12469437652811736, 0.045454545454545456, 'gini = 0.438\nsamples = 2\nvalue = [0.739, 1.547]'),
#  Text(0.12836185819070906, 0.13636363636363635, 'duration <= 238.145\ngini = 0.438\nsamples = 4\nvalue = [1.478, 3.093]'),
#  Text(0.1271393643031785, 0.045454545454545456, 'gini = 0.0\nsamples = 2\nvalue = [0.0, 3.093]'),
#  Text(0.1295843520782396, 0.045454545454545456, 'gini = 0.0\nsamples = 2\nvalue = [1.478, 0.0]'),
#  Text(0.15036674816625917, 0.4090909090909091, 'housing_yes <= 0.5\ngini = 0.178\nsamples = 2351\nvalue = [1650.571, 180.966]'),
#  Text(0.14058679706601468, 0.3181818181818182, 'previous <= 0.5\ngini = 0.363\nsamples = 731\nvalue = [469.903, 146.939]'),
#  Text(0.1356968215158924, 0.22727272727272727, 'month_mar <= 0.5\ngini = 0.292\nsamples = 577\nvalue = [386.414, 83.523]'),
#  Text(0.1332518337408313, 0.13636363636363635, 'duration <= 290.399\ngini = 0.274\nsamples = 562\nvalue = [379.764, 74.243]'),
#  Text(0.13202933985330073, 0.045454545454545456, 'gini = 0.185\nsamples = 366\nvalue = [256.378, 29.388]'),
#  Text(0.13447432762836187, 0.045454545454545456, 'gini = 0.391\nsamples = 196\nvalue = [123.386, 44.855]'),
#  Text(0.13814180929095354, 0.13636363636363635, 'loan_yes <= 0.5\ngini = 0.486\nsamples = 15\nvalue = [6.65, 9.28]'),
#  Text(0.13691931540342298, 0.045454545454545456, 'gini = 0.366\nsamples = 10\nvalue = [2.955, 9.28]'),
#  Text(0.1393643031784841, 0.045454545454545456, 'gini = 0.0\nsamples = 5\nvalue = [3.694, 0.0]'),
#  Text(0.14547677261613692, 0.22727272727272727, 'amount <= 219.5\ngini = 0.491\nsamples = 154\nvalue = [83.489, 63.416]'),
#  Text(0.1430317848410758, 0.13636363636363635, 'month_sep <= 0.5\ngini = 0.364\nsamples = 46\nvalue = [29.554, 9.28]'),
#  Text(0.14180929095354522, 0.045454545454545456, 'gini = 0.286\nsamples = 44\nvalue = [29.554, 6.187]'),
#  Text(0.14425427872860636, 0.045454545454545456, 'gini = 0.0\nsamples = 2\nvalue = [0.0, 3.093]'),
#  Text(0.14792176039119803, 0.13636363636363635, 'previous <= 7.5\ngini = 0.5\nsamples = 108\nvalue = [53.935, 54.135]'),
#  Text(0.1466992665036675, 0.045454545454545456, 'gini = 0.496\nsamples = 96\nvalue = [45.069, 54.135]'),
#  Text(0.1491442542787286, 0.045454545454545456, 'gini = 0.0\nsamples = 12\nvalue = [8.866, 0.0]'),
#  Text(0.16014669926650366, 0.3181818181818182, 'duration <= 315.604\ngini = 0.054\nsamples = 1620\nvalue = [1180.668, 34.028]'),
#  Text(0.1552567237163814, 0.22727272727272727, 'age <= 27.5\ngini = 0.033\nsamples = 1369\nvalue = [1003.346, 17.014]'),
#  Text(0.1528117359413203, 0.13636363636363635, 'amount <= 424.0\ngini = 0.139\nsamples = 134\nvalue = [95.31, 7.734]'),
#  Text(0.15158924205378974, 0.045454545454545456, 'gini = 0.0\nsamples = 75\nvalue = [55.413, 0.0]'),
#  Text(0.15403422982885084, 0.045454545454545456, 'gini = 0.272\nsamples = 59\nvalue = [39.897, 7.734]'),
#  Text(0.15770171149144255, 0.13636363636363635, 'previous <= 6.5\ngini = 0.02\nsamples = 1235\nvalue = [908.036, 9.28]'),
#  Text(0.15647921760391198, 0.045454545454545456, 'gini = 0.017\nsamples = 1225\nvalue = [901.386, 7.734]'),
#  Text(0.15892420537897312, 0.045454545454545456, 'gini = 0.306\nsamples = 10\nvalue = [6.65, 1.547]'),
#  Text(0.16503667481662593, 0.22727272727272727, 'month_jun <= 0.5\ngini = 0.16\nsamples = 251\nvalue = [177.322, 17.014]'),
#  Text(0.1625916870415648, 0.13636363636363635, 'duration <= 315.657\ngini = 0.136\nsamples = 246\nvalue = [175.105, 13.92]'),
#  Text(0.16136919315403422, 0.045454545454545456, 'gini = 0.0\nsamples = 1\nvalue = [0.0, 1.547]'),
#  Text(0.16381418092909536, 0.045454545454545456, 'gini = 0.123\nsamples = 245\nvalue = [175.105, 12.374]'),
#  Text(0.16748166259168704, 0.13636363636363635, 'duration <= 319.841\ngini = 0.486\nsamples = 5\nvalue = [2.217, 3.093]'),
#  Text(0.16625916870415647, 0.045454545454545456, 'gini = 0.0\nsamples = 2\nvalue = [1.478, 0.0]'),
#  Text(0.1687041564792176, 0.045454545454545456, 'gini = 0.311\nsamples = 3\nvalue = [0.739, 3.093]'),
#  Text(0.18474938875305624, 0.5, 'previous <= 1.5\ngini = 0.497\nsamples = 210\nvalue = [110.087, 94.35]'),
#  Text(0.18123471882640588, 0.4090909090909091, 'age <= 78.5\ngini = 0.468\nsamples = 158\nvalue = [90.877, 54.135]'),
#  Text(0.17787286063569682, 0.3181818181818182, 'duration <= 285.294\ngini = 0.446\nsamples = 149\nvalue = [88.661, 44.855]'),
#  Text(0.17481662591687042, 0.22727272727272727, 'amount <= 1379.0\ngini = 0.306\nsamples = 90\nvalue = [59.846, 13.92]'),
#  Text(0.17237163814180928, 0.13636363636363635, 'age <= 73.5\ngini = 0.083\nsamples = 47\nvalue = [33.987, 1.547]'),
#  Text(0.17114914425427874, 0.045454545454545456, 'gini = 0.0\nsamples = 42\nvalue = [31.031, 0.0]'),
#  Text(0.17359413202933985, 0.045454545454545456, 'gini = 0.451\nsamples = 5\nvalue = [2.955, 1.547]'),
#  Text(0.17726161369193155, 0.13636363636363635, 'duration <= 255.702\ngini = 0.438\nsamples = 43\nvalue = [25.859, 12.374]'),
#  Text(0.17603911980440098, 0.045454545454545456, 'gini = 0.495\nsamples = 19\nvalue = [8.866, 10.827]'),
#  Text(0.1784841075794621, 0.045454545454545456, 'gini = 0.153\nsamples = 24\nvalue = [16.993, 1.547]'),
#  Text(0.18092909535452323, 0.22727272727272727, 'age <= 63.5\ngini = 0.499\nsamples = 59\nvalue = [28.815, 30.934]'),
#  Text(0.17970660146699266, 0.13636363636363635, 'gini = 0.0\nsamples = 4\nvalue = [0.0, 6.187]'),
#  Text(0.1821515892420538, 0.13636363636363635, 'duration <= 286.709\ngini = 0.497\nsamples = 55\nvalue = [28.815, 24.748]'),
#  Text(0.18092909535452323, 0.045454545454545456, 'gini = 0.0\nsamples = 3\nvalue = [0.0, 4.64]'),
#  Text(0.18337408312958436, 0.045454545454545456, 'gini = 0.484\nsamples = 52\nvalue = [28.815, 20.107]'),
#  Text(0.1845965770171149, 0.3181818181818182, 'duration <= 272.785\ngini = 0.311\nsamples = 9\nvalue = [2.217, 9.28]'),
#  Text(0.18337408312958436, 0.22727272727272727, 'gini = 0.0\nsamples = 6\nvalue = [0.0, 9.28]'),
#  Text(0.18581907090464547, 0.22727272727272727, 'gini = 0.0\nsamples = 3\nvalue = [2.217, 0.0]'),
#  Text(0.1882640586797066, 0.4090909090909091, 'duration <= 242.237\ngini = 0.438\nsamples = 52\nvalue = [19.21, 40.215]'),
#  Text(0.18704156479217604, 0.3181818181818182, 'gini = 0.0\nsamples = 11\nvalue = [0.0, 17.014]'),
#  Text(0.18948655256723718, 0.3181818181818182, 'duration <= 275.204\ngini = 0.496\nsamples = 41\nvalue = [19.21, 23.201]'),
#  Text(0.1882640586797066, 0.22727272727272727, 'gini = 0.0\nsamples = 11\nvalue = [8.127, 0.0]'),
#  Text(0.19070904645476772, 0.22727272727272727, 'amount <= 4872.5\ngini = 0.438\nsamples = 30\nvalue = [11.083, 23.201]'),
#  Text(0.18948655256723718, 0.13636363636363635, 'previous <= 4.5\ngini = 0.346\nsamples = 24\nvalue = [6.65, 23.201]'),
#  Text(0.1882640586797066, 0.045454545454545456, 'gini = 0.211\nsamples = 18\nvalue = [2.955, 21.654]'),
#  Text(0.19070904645476772, 0.045454545454545456, 'gini = 0.416\nsamples = 6\nvalue = [3.694, 1.547]'),
#  Text(0.19193154034229828, 0.13636363636363635, 'gini = 0.0\nsamples = 6\nvalue = [4.433, 0.0]'),
#  Text(0.2352536674816626, 0.5909090909090909, 'duration <= 237.733\ngini = 0.357\nsamples = 1886\nvalue = [1217.61, 368.12]'),
#  Text(0.21561735941320292, 0.5, 'duration <= 236.572\ngini = 0.23\nsamples = 662\nvalue = [455.865, 69.602]'),
#  Text(0.20874083129584353, 0.4090909090909091, 'housing_yes <= 0.5\ngini = 0.474\nsamples = 190\nvalue = [107.871, 68.056]'),
#  Text(0.2017114914425428, 0.3181818181818182, 'age <= 48.5\ngini = 0.496\nsamples = 143\nvalue = [75.362, 63.416]'),
#  Text(0.19682151589242053, 0.22727272727272727, 'duration <= 216.475\ngini = 0.479\nsamples = 74\nvalue = [31.77, 47.948]'),
#  Text(0.19437652811735942, 0.13636363636363635, 'age <= 44.5\ngini = 0.384\nsamples = 14\nvalue = [8.866, 3.093]'),
#  Text(0.19315403422982885, 0.045454545454545456, 'gini = 0.0\nsamples = 7\nvalue = [5.172, 0.0]'),
#  Text(0.19559902200489, 0.045454545454545456, 'gini = 0.496\nsamples = 7\nvalue = [3.694, 3.093]'),
#  Text(0.19926650366748166, 0.13636363636363635, 'amount <= 310.5\ngini = 0.448\nsamples = 60\nvalue = [22.904, 44.855]'),
#  Text(0.1980440097799511, 0.045454545454545456, 'gini = 0.489\nsamples = 23\nvalue = [12.56, 9.28]'),
#  Text(0.20048899755501223, 0.045454545454545456, 'gini = 0.349\nsamples = 37\nvalue = [10.344, 35.575]'),
#  Text(0.20660146699266504, 0.22727272727272727, 'duration <= 235.075\ngini = 0.387\nsamples = 69\nvalue = [43.592, 15.467]'),
#  Text(0.2041564792176039, 0.13636363636363635, 'age <= 56.5\ngini = 0.265\nsamples = 61\nvalue = [41.375, 7.734]'),
#  Text(0.20293398533007334, 0.045454545454545456, 'gini = 0.344\nsamples = 42\nvalue = [27.337, 7.734]'),
#  Text(0.20537897310513448, 0.045454545454545456, 'gini = 0.0\nsamples = 19\nvalue = [14.038, 0.0]'),
#  Text(0.20904645476772615, 0.13636363636363635, 'job_management <= 0.5\ngini = 0.346\nsamples = 8\nvalue = [2.217, 7.734]'),
#  Text(0.2078239608801956, 0.045454545454545456, 'gini = 0.484\nsamples = 4\nvalue = [2.217, 1.547]'),
#  Text(0.21026894865525672, 0.045454545454545456, 'gini = 0.0\nsamples = 4\nvalue = [0.0, 6.187]'),
#  Text(0.21577017114914426, 0.3181818181818182, 'age <= 23.0\ngini = 0.219\nsamples = 47\nvalue = [32.509, 4.64]'),
#  Text(0.21271393643031786, 0.22727272727272727, 'duration <= 227.821\ngini = 0.311\nsamples = 3\nvalue = [0.739, 3.093]'),
#  Text(0.2114914425427873, 0.13636363636363635, 'gini = 0.0\nsamples = 1\nvalue = [0.739, 0.0]'),
#  Text(0.2139364303178484, 0.13636363636363635, 'gini = 0.0\nsamples = 2\nvalue = [0.0, 3.093]'),
#  Text(0.21882640586797067, 0.22727272727272727, 'education_tertiary <= 0.5\ngini = 0.089\nsamples = 44\nvalue = [31.77, 1.547]'),
#  Text(0.21638141809290953, 0.13636363636363635, 'education_secondary <= 0.5\ngini = 0.0\nsamples = 38\nvalue = [28.076, 0.0]'),
#  Text(0.21515892420537897, 0.045454545454545456, 'gini = 0.0\nsamples = 5\nvalue = [3.694, 0.0]'),
#  Text(0.2176039119804401, 0.045454545454545456, 'gini = 0.0\nsamples = 33\nvalue = [24.382, 0.0]'),
#  Text(0.22127139364303178, 0.13636363636363635, 'job_technician <= 0.5\ngini = 0.416\nsamples = 6\nvalue = [3.694, 1.547]'),
#  Text(0.2200488997555012, 0.045454545454545456, 'gini = 0.0\nsamples = 4\nvalue = [2.955, 0.0]'),
#  Text(0.22249388753056235, 0.045454545454545456, 'gini = 0.438\nsamples = 2\nvalue = [0.739, 1.547]'),
#  Text(0.22249388753056235, 0.4090909090909091, 'age <= 54.5\ngini = 0.009\nsamples = 472\nvalue = [347.994, 1.547]'),
#  Text(0.22127139364303178, 0.3181818181818182, 'gini = 0.0\nsamples = 439\nvalue = [324.351, 0.0]'),
#  Text(0.2237163814180929, 0.3181818181818182, 'job_blue-collar <= 0.5\ngini = 0.115\nsamples = 33\nvalue = [23.643, 1.547]'),
#  Text(0.22249388753056235, 0.22727272727272727, 'gini = 0.0\nsamples = 30\nvalue = [22.165, 0.0]'),
#  Text(0.22493887530562348, 0.22727272727272727, 'amount <= 330.0\ngini = 0.5\nsamples = 3\nvalue = [1.478, 1.547]'),
#  Text(0.2237163814180929, 0.13636363636363635, 'gini = 0.0\nsamples = 1\nvalue = [0.0, 1.547]'),
#  Text(0.22616136919315402, 0.13636363636363635, 'gini = 0.0\nsamples = 2\nvalue = [1.478, 0.0]'),
#  Text(0.25488997555012227, 0.5, 'housing_yes <= 0.5\ngini = 0.405\nsamples = 1224\nvalue = [761.745, 298.517]'),
#  Text(0.24205378973105135, 0.4090909090909091, 'job_retired <= 0.5\ngini = 0.498\nsamples = 293\nvalue = [140.38, 159.312]'),
#  Text(0.23594132029339854, 0.3181818181818182, 'loan_yes <= 0.5\ngini = 0.489\nsamples = 257\nvalue = [115.259, 156.219]'),
#  Text(0.2310513447432763, 0.22727272727272727, 'duration <= 275.47\ngini = 0.456\nsamples = 177\nvalue = [69.451, 128.378]'),
#  Text(0.22860635696821516, 0.13636363636363635, 'age <= 45.5\ngini = 0.496\nsamples = 135\nvalue = [63.54, 75.789]'),
#  Text(0.2273838630806846, 0.045454545454545456, 'gini = 0.101\nsamples = 19\nvalue = [1.478, 26.294]'),
#  Text(0.22982885085574573, 0.045454545454545456, 'gini = 0.494\nsamples = 116\nvalue = [62.063, 49.495]'),
#  Text(0.2334963325183374, 0.13636363636363635, 'age <= 55.5\ngini = 0.182\nsamples = 42\nvalue = [5.911, 52.589]'),
#  Text(0.23227383863080683, 0.045454545454545456, 'gini = 0.042\nsamples = 23\nvalue = [0.739, 34.028]'),
#  Text(0.23471882640586797, 0.045454545454545456, 'gini = 0.341\nsamples = 19\nvalue = [5.172, 18.561]'),
#  Text(0.24083129584352078, 0.22727272727272727, 'age <= 55.5\ngini = 0.47\nsamples = 80\nvalue = [45.808, 27.841]'),
#  Text(0.23838630806845965, 0.13636363636363635, 'duration <= 242.815\ngini = 0.441\nsamples = 74\nvalue = [44.33, 21.654]'),
#  Text(0.2371638141809291, 0.045454545454545456, 'gini = 0.0\nsamples = 2\nvalue = [0.0, 3.093]'),
#  Text(0.2396088019559902, 0.045454545454545456, 'gini = 0.416\nsamples = 72\nvalue = [44.33, 18.561]'),
#  Text(0.24327628361858192, 0.13636363636363635, 'duration <= 301.688\ngini = 0.311\nsamples = 6\nvalue = [1.478, 6.187]'),
#  Text(0.24205378973105135, 0.045454545454545456, 'gini = 0.0\nsamples = 4\nvalue = [0.0, 6.187]'),
#  Text(0.24449877750611246, 0.045454545454545456, 'gini = 0.0\nsamples = 2\nvalue = [1.478, 0.0]'),
#  Text(0.24816625916870416, 0.3181818181818182, 'age <= 60.5\ngini = 0.195\nsamples = 36\nvalue = [25.121, 3.093]'),
#  Text(0.2469437652811736, 0.22727272727272727, 'default_yes <= 0.5\ngini = 0.109\nsamples = 35\nvalue = [25.121, 1.547]'),
#  Text(0.24572127139364303, 0.13636363636363635, 'gini = 0.0\nsamples = 34\nvalue = [25.121, 0.0]'),
#  Text(0.24816625916870416, 0.13636363636363635, 'gini = -0.0\nsamples = 1\nvalue = [0.0, 1.547]'),
#  Text(0.24938875305623473, 0.22727272727272727, 'gini = -0.0\nsamples = 1\nvalue = [0.0, 1.547]'),
#  Text(0.26772616136919314, 0.4090909090909091, 'duration <= 297.173\ngini = 0.299\nsamples = 931\nvalue = [621.365, 139.205]'),
#  Text(0.25794621026894865, 0.3181818181818182, 'age <= 34.5\ngini = 0.186\nsamples = 553\nvalue = [387.153, 44.855]'),
#  Text(0.2530562347188264, 0.22727272727272727, 'amount <= 9210.0\ngini = 0.236\nsamples = 369\nvalue = [253.422, 40.215]'),
#  Text(0.2506112469437653, 0.13636363636363635, 'job_management <= 0.5\ngini = 0.224\nsamples = 365\nvalue = [251.945, 37.121]'),
#  Text(0.24938875305623473, 0.045454545454545456, 'gini = 0.245\nsamples = 325\nvalue = [222.391, 37.121]'),
#  Text(0.25183374083129584, 0.045454545454545456, 'gini = 0.0\nsamples = 40\nvalue = [29.554, 0.0]'),
#  Text(0.2555012224938875, 0.13636363636363635, 'marital_single <= 0.5\ngini = 0.438\nsamples = 4\nvalue = [1.478, 3.093]'),
#  Text(0.254278728606357, 0.045454545454545456, 'gini = 0.0\nsamples = 2\nvalue = [1.478, 0.0]'),
#  Text(0.2567237163814181, 0.045454545454545456, 'gini = 0.0\nsamples = 2\nvalue = [0.0, 3.093]'),
#  Text(0.2628361858190709, 0.22727272727272727, 'job_services <= 0.5\ngini = 0.065\nsamples = 184\nvalue = [133.73, 4.64]'),
#  Text(0.2603911980440098, 0.13636363636363635, 'amount <= 190.5\ngini = 0.025\nsamples = 166\nvalue = [121.909, 1.547]'),
#  Text(0.2591687041564792, 0.045454545454545456, 'gini = 0.082\nsamples = 48\nvalue = [34.726, 1.547]'),
#  Text(0.2616136919315403, 0.045454545454545456, 'gini = -0.0\nsamples = 118\nvalue = [87.183, 0.0]'),
#  Text(0.265281173594132, 0.13636363636363635, 'duration <= 292.148\ngini = 0.329\nsamples = 18\nvalue = [11.821, 3.093]'),
#  Text(0.26405867970660146, 0.045454545454545456, 'gini = 0.0\nsamples = 15\nvalue = [11.083, 0.0]'),
#  Text(0.2665036674816626, 0.045454545454545456, 'gini = 0.311\nsamples = 3\nvalue = [0.739, 3.093]'),
#  Text(0.2775061124694376, 0.3181818181818182, 'age <= 33.5\ngini = 0.409\nsamples = 378\nvalue = [234.213, 94.35]'),
#  Text(0.2726161369193154, 0.22727272727272727, 'duration <= 313.431\ngini = 0.498\nsamples = 124\nvalue = [64.279, 57.229]'),
#  Text(0.2701711491442543, 0.13636363636363635, 'duration <= 310.234\ngini = 0.495\nsamples = 79\nvalue = [36.942, 44.855]'),
#  Text(0.26894865525672373, 0.045454545454545456, 'gini = 0.499\nsamples = 63\nvalue = [32.509, 29.388]'),
#  Text(0.2713936430317848, 0.045454545454545456, 'gini = 0.346\nsamples = 16\nvalue = [4.433, 15.467]'),
#  Text(0.27506112469437655, 0.13636363636363635, 'job_blue-collar <= 0.5\ngini = 0.429\nsamples = 45\nvalue = [27.337, 12.374]'),
#  Text(0.27383863080684595, 0.045454545454545456, 'gini = 0.341\nsamples = 34\nvalue = [22.165, 6.187]'),
#  Text(0.2762836185819071, 0.045454545454545456, 'gini = 0.496\nsamples = 11\nvalue = [5.172, 6.187]'),
#  Text(0.2823960880195599, 0.22727272727272727, 'education_unknown <= 0.5\ngini = 0.294\nsamples = 254\nvalue = [169.933, 37.121]'),
#  Text(0.27995110024449876, 0.13636363636363635, 'age <= 41.5\ngini = 0.265\nsamples = 245\nvalue = [166.239, 30.934]'),
#  Text(0.2787286063569682, 0.045454545454545456, 'gini = 0.352\nsamples = 154\nvalue = [99.744, 29.388]'),
#  Text(0.28117359413202936, 0.045454545454545456, 'gini = 0.044\nsamples = 91\nvalue = [66.496, 1.547]'),
#  Text(0.28484107579462103, 0.13636363636363635, 'duration <= 314.708\ngini = 0.468\nsamples = 9\nvalue = [3.694, 6.187]'),
#  Text(0.28361858190709044, 0.045454545454545456, 'gini = 0.0\nsamples = 4\nvalue = [2.955, 0.0]'),
#  Text(0.2860635696821516, 0.045454545454545456, 'gini = 0.191\nsamples = 5\nvalue = [0.739, 6.187]'),
#  Text(0.35956601466992666, 0.7727272727272727, 'duration <= 213.664\ngini = 0.5\nsamples = 3768\nvalue = [1918.031, 1812.758]'),
#  Text(0.3055088630806846, 0.6818181818181818, 'duration <= 98.177\ngini = 0.237\nsamples = 444\nvalue = [82.011, 515.058]'),
#  Text(0.2921760391198044, 0.5909090909090909, 'job_entrepreneur <= 0.5\ngini = 0.369\nsamples = 15\nvalue = [9.605, 3.093]'),
#  Text(0.289119804400978, 0.5, 'duration <= 84.72\ngini = 0.253\nsamples = 13\nvalue = [8.866, 1.547]'),
#  Text(0.2866748166259169, 0.4090909090909091, 'duration <= 80.877\ngini = 0.451\nsamples = 5\nvalue = [2.955, 1.547]'),
#  Text(0.28545232273838633, 0.3181818181818182, 'gini = 0.0\nsamples = 4\nvalue = [2.955, 0.0]'),
#  Text(0.2878973105134474, 0.3181818181818182, 'gini = 0.0\nsamples = 1\nvalue = [0.0, 1.547]'),
#  Text(0.29156479217603914, 0.4090909090909091, 'month_aug <= 0.5\ngini = 0.0\nsamples = 8\nvalue = [5.911, 0.0]'),
#  Text(0.29034229828850855, 0.3181818181818182, 'gini = 0.0\nsamples = 4\nvalue = [2.955, 0.0]'),
#  Text(0.2927872860635697, 0.3181818181818182, 'gini = 0.0\nsamples = 4\nvalue = [2.955, 0.0]'),
#  Text(0.2952322738386308, 0.5, 'marital_married <= 0.5\ngini = 0.438\nsamples = 2\nvalue = [0.739, 1.547]'),
#  Text(0.2940097799511002, 0.4090909090909091, 'gini = 0.0\nsamples = 1\nvalue = [0.739, 0.0]'),
#  Text(0.29645476772616136, 0.4090909090909091, 'gini = 0.0\nsamples = 1\nvalue = [0.0, 1.547]'),
#  Text(0.3188416870415648, 0.5909090909090909, 'age <= 47.5\ngini = 0.217\nsamples = 429\nvalue = [72.406, 511.965]'),
#  Text(0.30761002444987773, 0.5, 'duration <= 156.703\ngini = 0.188\nsamples = 396\nvalue = [57.63, 491.857]'),
#  Text(0.2998166259168704, 0.4090909090909091, 'age <= 35.5\ngini = 0.378\nsamples = 94\nvalue = [28.815, 85.07]'),
#  Text(0.2952322738386308, 0.3181818181818182, 'month_jun <= 0.5\ngini = 0.283\nsamples = 73\nvalue = [16.255, 78.883]'),
#  Text(0.2921760391198044, 0.22727272727272727, 'month_aug <= 0.5\ngini = 0.266\nsamples = 71\nvalue = [14.777, 78.883]'),
#  Text(0.28973105134474325, 0.13636363636363635, 'duration <= 154.113\ngini = 0.167\nsamples = 40\nvalue = [5.172, 51.042]'),
#  Text(0.2885085574572127, 0.045454545454545456, 'gini = 0.106\nsamples = 36\nvalue = [2.955, 49.495]'),
#  Text(0.29095354523227385, 0.045454545454545456, 'gini = 0.484\nsamples = 4\nvalue = [2.217, 1.547]'),
#  Text(0.2946210268948655, 0.13636363636363635, 'amount <= 40.5\ngini = 0.381\nsamples = 31\nvalue = [9.605, 27.841]'),
#  Text(0.293398533007335, 0.045454545454545456, 'gini = 0.0\nsamples = 7\nvalue = [0.0, 10.827]'),
#  Text(0.29584352078239606, 0.045454545454545456, 'gini = 0.461\nsamples = 24\nvalue = [9.605, 17.014]'),
#  Text(0.2982885085574572, 0.22727272727272727, 'job_services <= 0.5\ngini = 0.0\nsamples = 2\nvalue = [1.478, 0.0]'),
#  Text(0.29706601466992666, 0.13636363636363635, 'gini = 0.0\nsamples = 1\nvalue = [0.739, 0.0]'),
#  Text(0.2995110024449878, 0.13636363636363635, 'gini = 0.0\nsamples = 1\nvalue = [0.739, 0.0]'),
#  Text(0.30440097799511, 0.3181818181818182, 'education_unknown <= 0.5\ngini = 0.442\nsamples = 21\nvalue = [12.56, 6.187]'),
#  Text(0.30317848410757947, 0.22727272727272727, 'job_housemaid <= 0.5\ngini = 0.394\nsamples = 20\nvalue = [12.56, 4.64]'),
#  Text(0.3019559902200489, 0.13636363636363635, 'campaign <= 9.5\ngini = 0.317\nsamples = 19\nvalue = [12.56, 3.093]'),
#  Text(0.30073349633251834, 0.045454545454545456, 'gini = 0.195\nsamples = 18\nvalue = [12.56, 1.547]'),
#  Text(0.30317848410757947, 0.045454545454545456, 'gini = 0.0\nsamples = 1\nvalue = [0.0, 1.547]'),
#  Text(0.30440097799511, 0.13636363636363635, 'gini = 0.0\nsamples = 1\nvalue = [0.0, 1.547]'),
#  Text(0.3056234718826406, 0.22727272727272727, 'gini = -0.0\nsamples = 1\nvalue = [0.0, 1.547]'),
#  Text(0.3154034229828851, 0.4090909090909091, 'housing_yes <= 0.5\ngini = 0.124\nsamples = 302\nvalue = [28.815, 406.788]'),
#  Text(0.3141809290953545, 0.3181818181818182, 'age <= 37.5\ngini = 0.118\nsamples = 300\nvalue = [27.337, 406.788]'),
#  Text(0.3092909535452323, 0.22727272727272727, 'duration <= 213.63\ngini = 0.049\nsamples = 196\nvalue = [7.388, 287.69]'),
#  Text(0.30684596577017115, 0.13636363636363635, 'duration <= 186.587\ngini = 0.044\nsamples = 194\nvalue = [6.65, 286.143]'),
#  Text(0.3056234718826406, 0.045454545454545456, 'gini = 0.1\nsamples = 86\nvalue = [6.65, 119.098]'),
#  Text(0.3080684596577017, 0.045454545454545456, 'gini = -0.0\nsamples = 108\nvalue = [0.0, 167.046]'),
#  Text(0.3117359413202934, 0.13636363636363635, 'education_secondary <= 0.5\ngini = 0.438\nsamples = 2\nvalue = [0.739, 1.547]'),
#  Text(0.3105134474327628, 0.045454545454545456, 'gini = 0.0\nsamples = 1\nvalue = [0.739, 0.0]'),
#  Text(0.31295843520782396, 0.045454545454545456, 'gini = 0.0\nsamples = 1\nvalue = [0.0, 1.547]'),
#  Text(0.31907090464547677, 0.22727272727272727, 'duration <= 188.064\ngini = 0.246\nsamples = 104\nvalue = [19.949, 119.098]'),
#  Text(0.31662591687041564, 0.13636363636363635, 'amount <= -0.5\ngini = 0.41\nsamples = 48\nvalue = [16.255, 40.215]'),
#  Text(0.3154034229828851, 0.045454545454545456, 'gini = 0.0\nsamples = 3\nvalue = [2.217, 0.0]'),
#  Text(0.31784841075794623, 0.045454545454545456, 'gini = 0.384\nsamples = 45\nvalue = [14.038, 40.215]'),
#  Text(0.3215158924205379, 0.13636363636363635, 'duration <= 213.35\ngini = 0.085\nsamples = 56\nvalue = [3.694, 78.883]'),
#  Text(0.3202933985330073, 0.045454545454545456, 'gini = 0.07\nsamples = 55\nvalue = [2.955, 78.883]'),
#  Text(0.32273838630806845, 0.045454545454545456, 'gini = 0.0\nsamples = 1\nvalue = [0.739, 0.0]'),
#  Text(0.31662591687041564, 0.3181818181818182, 'gini = -0.0\nsamples = 2\nvalue = [1.478, 0.0]'),
#  Text(0.33007334963325186, 0.5, 'duration <= 186.769\ngini = 0.488\nsamples = 33\nvalue = [14.777, 20.107]'),
#  Text(0.32885085574572126, 0.4090909090909091, 'gini = 0.0\nsamples = 5\nvalue = [3.694, 0.0]'),
#  Text(0.3312958435207824, 0.4090909090909091, 'duration <= 209.565\ngini = 0.458\nsamples = 28\nvalue = [11.083, 20.107]'),
#  Text(0.32885085574572126, 0.3181818181818182, 'duration <= 202.477\ngini = 0.498\nsamples = 20\nvalue = [9.605, 10.827]'),
#  Text(0.3276283618581907, 0.22727272727272727, 'amount <= 588.0\ngini = 0.379\nsamples = 12\nvalue = [3.694, 10.827]'),
#  Text(0.3264058679706601, 0.13636363636363635, 'job_unknown <= 0.5\ngini = 0.211\nsamples = 9\nvalue = [1.478, 10.827]'),
#  Text(0.3251833740831296, 0.045454545454545456, 'gini = 0.12\nsamples = 8\nvalue = [0.739, 10.827]'),
#  Text(0.3276283618581907, 0.045454545454545456, 'gini = 0.0\nsamples = 1\nvalue = [0.739, 0.0]'),
#  Text(0.32885085574572126, 0.13636363636363635, 'gini = 0.0\nsamples = 3\nvalue = [2.217, 0.0]'),
#  Text(0.33007334963325186, 0.22727272727272727, 'gini = -0.0\nsamples = 8\nvalue = [5.911, 0.0]'),
#  Text(0.33374083129584353, 0.3181818181818182, 'amount <= 228.0\ngini = 0.237\nsamples = 8\nvalue = [1.478, 9.28]'),
#  Text(0.33251833740831294, 0.22727272727272727, 'gini = 0.0\nsamples = 1\nvalue = [0.739, 0.0]'),
#  Text(0.33496332518337407, 0.22727272727272727, 'amount <= 4799.5\ngini = 0.137\nsamples = 7\nvalue = [0.739, 9.28]'),
#  Text(0.33374083129584353, 0.13636363636363635, 'gini = 0.0\nsamples = 6\nvalue = [0.0, 9.28]'),
#  Text(0.33618581907090467, 0.13636363636363635, 'gini = 0.0\nsamples = 1\nvalue = [0.739, 0.0]'),
#  Text(0.41362316625916873, 0.6818181818181818, 'duration <= 237.325\ngini = 0.485\nsamples = 3324\nvalue = [1836.02, 1297.699]'),
#  Text(0.3821057457212714, 0.5909090909090909, 'duration <= 236.339\ngini = 0.341\nsamples = 1478\nvalue = [963.449, 269.13]'),
#  Text(0.3653728606356968, 0.5, 'age <= 47.5\ngini = 0.498\nsamples = 463\nvalue = [222.391, 250.569]'),
#  Text(0.3526894865525672, 0.4090909090909091, 'housing_yes <= 0.5\ngini = 0.462\nsamples = 291\nvalue = [116.737, 205.714]'),
#  Text(0.34596577017114916, 0.3181818181818182, 'loan_yes <= 0.5\ngini = 0.407\nsamples = 242\nvalue = [81.273, 204.167]'),
#  Text(0.3410757946210269, 0.22727272727272727, 'age <= 40.5\ngini = 0.327\nsamples = 196\nvalue = [50.98, 196.434]'),
#  Text(0.33863080684596575, 0.13636363636363635, 'month_jan <= 0.5\ngini = 0.172\nsamples = 100\nvalue = [13.299, 126.831]'),
#  Text(0.3374083129584352, 0.045454545454545456, 'gini = 0.149\nsamples = 96\nvalue = [11.083, 125.284]'),
#  Text(0.33985330073349634, 0.045454545454545456, 'gini = 0.484\nsamples = 4\nvalue = [2.217, 1.547]'),
#  Text(0.343520782396088, 0.13636363636363635, 'duration <= 216.747\ngini = 0.456\nsamples = 96\nvalue = [37.681, 69.602]'),
#  Text(0.3422982885085575, 0.045454545454545456, 'gini = 0.369\nsamples = 15\nvalue = [9.605, 3.093]'),
#  Text(0.34474327628361856, 0.045454545454545456, 'gini = 0.417\nsamples = 81\nvalue = [28.076, 66.509]'),
#  Text(0.3508557457212714, 0.22727272727272727, 'duration <= 233.204\ngini = 0.324\nsamples = 46\nvalue = [30.292, 7.734]'),
#  Text(0.3484107579462103, 0.13636363636363635, 'month_aug <= 0.5\ngini = 0.109\nsamples = 35\nvalue = [25.121, 1.547]'),
#  Text(0.3471882640586797, 0.045454545454545456, 'gini = 0.0\nsamples = 27\nvalue = [19.949, 0.0]'),
#  Text(0.34963325183374083, 0.045454545454545456, 'gini = 0.354\nsamples = 8\nvalue = [5.172, 1.547]'),
#  Text(0.3533007334963325, 0.13636363636363635, 'duration <= 234.718\ngini = 0.496\nsamples = 11\nvalue = [5.172, 6.187]'),
#  Text(0.35207823960880197, 0.045454545454545456, 'gini = 0.311\nsamples = 6\nvalue = [1.478, 6.187]'),
#  Text(0.3545232273838631, 0.045454545454545456, 'gini = 0.0\nsamples = 5\nvalue = [3.694, 0.0]'),
#  Text(0.3594132029339853, 0.3181818181818182, 'job_student <= 0.5\ngini = 0.08\nsamples = 49\nvalue = [35.464, 1.547]'),
#  Text(0.3569682151589242, 0.22727272727272727, 'amount <= -317.5\ngini = 0.0\nsamples = 45\nvalue = [33.248, 0.0]'),
#  Text(0.35574572127139364, 0.13636363636363635, 'gini = 0.0\nsamples = 1\nvalue = [0.739, 0.0]'),
#  Text(0.3581907090464548, 0.13636363636363635, 'gini = 0.0\nsamples = 44\nvalue = [32.509, 0.0]'),
#  Text(0.36185819070904646, 0.22727272727272727, 'duration <= 225.046\ngini = 0.484\nsamples = 4\nvalue = [2.217, 1.547]'),
#  Text(0.3606356968215159, 0.13636363636363635, 'gini = 0.0\nsamples = 1\nvalue = [0.0, 1.547]'),
#  Text(0.363080684596577, 0.13636363636363635, 'contact_sending _document <= 0.5\ngini = 0.0\nsamples = 3\nvalue = [2.217, 0.0]'),
#  Text(0.36185819070904646, 0.045454545454545456, 'gini = 0.0\nsamples = 2\nvalue = [1.478, 0.0]'),
#  Text(0.3643031784841076, 0.045454545454545456, 'gini = 0.0\nsamples = 1\nvalue = [0.739, 0.0]'),
#  Text(0.3780562347188264, 0.4090909090909091, 'campaign <= 7.5\ngini = 0.418\nsamples = 172\nvalue = [105.654, 44.855]'),
#  Text(0.37102689486552565, 0.3181818181818182, 'duration <= 220.345\ngini = 0.377\nsamples = 144\nvalue = [91.616, 30.934]'),
#  Text(0.36674816625916873, 0.22727272727272727, 'month_jan <= 0.5\ngini = 0.165\nsamples = 44\nvalue = [31.031, 3.093]'),
#  Text(0.36552567237163813, 0.13636363636363635, 'gini = 0.0\nsamples = 42\nvalue = [31.031, 0.0]'),
#  Text(0.36797066014669927, 0.13636363636363635, 'duration <= 217.321\ngini = 0.0\nsamples = 2\nvalue = [0.0, 3.093]'),
#  Text(0.36674816625916873, 0.045454545454545456, 'gini = 0.0\nsamples = 1\nvalue = [0.0, 1.547]'),
#  Text(0.3691931540342298, 0.045454545454545456, 'gini = 0.0\nsamples = 1\nvalue = [0.0, 1.547]'),
#  Text(0.3753056234718826, 0.22727272727272727, 'amount <= 2042.0\ngini = 0.431\nsamples = 100\nvalue = [60.585, 27.841]'),
#  Text(0.37286063569682154, 0.13636363636363635, 'education_secondary <= 0.5\ngini = 0.357\nsamples = 79\nvalue = [50.98, 15.467]'),
#  Text(0.37163814180929094, 0.045454545454545456, 'gini = 0.201\nsamples = 52\nvalue = [36.203, 4.64]'),
#  Text(0.3740831295843521, 0.045454545454545456, 'gini = 0.488\nsamples = 27\nvalue = [14.777, 10.827]'),
#  Text(0.37775061124694376, 0.13636363636363635, 'amount <= 2403.5\ngini = 0.492\nsamples = 21\nvalue = [9.605, 12.374]'),
#  Text(0.3765281173594132, 0.045454545454545456, 'gini = 0.0\nsamples = 3\nvalue = [0.0, 4.64]'),
#  Text(0.37897310513447435, 0.045454545454545456, 'gini = 0.494\nsamples = 18\nvalue = [9.605, 7.734]'),
#  Text(0.38508557457212717, 0.3181818181818182, 'age <= 53.5\ngini = 0.5\nsamples = 28\nvalue = [14.038, 13.92]'),
#  Text(0.38386308068459657, 0.22727272727272727, 'contact_telephone <= 0.5\ngini = 0.438\nsamples = 18\nvalue = [6.65, 13.92]'),
#  Text(0.38264058679706603, 0.13636363636363635, 'campaign <= 11.0\ngini = 0.366\nsamples = 15\nvalue = [4.433, 13.92]'),
#  Text(0.38141809290953543, 0.045454545454545456, 'gini = 0.137\nsamples = 7\nvalue = [0.739, 9.28]'),
#  Text(0.38386308068459657, 0.045454545454545456, 'gini = 0.494\nsamples = 8\nvalue = [3.694, 4.64]'),
#  Text(0.38508557457212717, 0.13636363636363635, 'gini = -0.0\nsamples = 3\nvalue = [2.217, 0.0]'),
#  Text(0.3863080684596577, 0.22727272727272727, 'gini = -0.0\nsamples = 10\nvalue = [7.388, 0.0]'),
#  Text(0.39883863080684595, 0.5, 'age <= 60.5\ngini = 0.048\nsamples = 1015\nvalue = [741.057, 18.561]'),
#  Text(0.39425427872860636, 0.4090909090909091, 'duration <= 237.007\ngini = 0.008\nsamples = 1003\nvalue = [739.58, 3.093]'),
#  Text(0.39119804400978, 0.3181818181818182, 'job_retired <= 0.5\ngini = 0.004\nsamples = 998\nvalue = [736.624, 1.547]'),
#  Text(0.38875305623471884, 0.22727272727272727, 'job_unemployed <= 0.5\ngini = 0.0\nsamples = 977\nvalue = [721.848, 0.0]'),
#  Text(0.38753056234718825, 0.13636363636363635, 'gini = 0.0\nsamples = 944\nvalue = [697.466, 0.0]'),
#  Text(0.3899755501222494, 0.13636363636363635, 'gini = 0.0\nsamples = 33\nvalue = [24.382, 0.0]'),
#  Text(0.39364303178484106, 0.22727272727272727, 'month_aug <= 0.5\ngini = 0.172\nsamples = 21\nvalue = [14.777, 1.547]'),
#  Text(0.3924205378973105, 0.13636363636363635, 'gini = 0.0\nsamples = 16\nvalue = [11.821, 0.0]'),
#  Text(0.39486552567237165, 0.13636363636363635, 'education_secondary <= 0.5\ngini = 0.451\nsamples = 5\nvalue = [2.955, 1.547]'),
#  Text(0.39364303178484106, 0.045454545454545456, 'gini = 0.0\nsamples = 3\nvalue = [2.217, 0.0]'),
#  Text(0.3960880195599022, 0.045454545454545456, 'gini = 0.438\nsamples = 2\nvalue = [0.739, 1.547]'),
#  Text(0.3973105134474328, 0.3181818181818182, 'job_housemaid <= 0.5\ngini = 0.451\nsamples = 5\nvalue = [2.955, 1.547]'),
#  Text(0.3960880195599022, 0.22727272727272727, 'gini = 0.0\nsamples = 4\nvalue = [2.955, 0.0]'),
#  Text(0.39853300733496333, 0.22727272727272727, 'gini = 0.0\nsamples = 1\nvalue = [0.0, 1.547]'),
#  Text(0.4034229828850856, 0.4090909090909091, 'amount <= 30100.0\ngini = 0.159\nsamples = 12\nvalue = [1.478, 15.467]'),
#  Text(0.402200488997555, 0.3181818181818182, 'job_unknown <= 0.5\ngini = 0.087\nsamples = 11\nvalue = [0.739, 15.467]'),
#  Text(0.40097799511002447, 0.22727272727272727, 'gini = 0.0\nsamples = 10\nvalue = [0.0, 15.467]'),
#  Text(0.4034229828850856, 0.22727272727272727, 'gini = 0.0\nsamples = 1\nvalue = [0.739, 0.0]'),
#  Text(0.40464547677261614, 0.3181818181818182, 'gini = -0.0\nsamples = 1\nvalue = [0.739, 0.0]'),
#  Text(0.44514058679706603, 0.5909090909090909, 'housing_yes <= 0.5\ngini = 0.497\nsamples = 1846\nvalue = [872.571, 1028.57]'),
#  Text(0.4219132029339853, 0.5, 'loan_yes <= 0.5\ngini = 0.419\nsamples = 844\nvalue = [294.059, 689.838]'),
#  Text(0.4135085574572127, 0.4090909090909091, 'age <= 50.5\ngini = 0.335\nsamples = 581\nvalue = [155.157, 573.834]'),
# ...
#  Text(0.8215158924205379, 0.22727272727272727, 'previous <= 3.5\ngini = 0.14\nsamples = 532\nvalue = [57.63, 702.212]'),
#  Text(0.8190709046454768, 0.13636363636363635, 'campaign <= 30.5\ngini = 0.126\nsamples = 495\nvalue = [48.025, 665.09]'),
#  Text(0.8178484107579462, 0.045454545454545456, 'gini = 0.124\nsamples = 494\nvalue = [47.286, 665.09]'),
#  Text(0.8202933985330073, 0.045454545454545456, 'gini = 0.0\nsamples = 1\nvalue = [0.739, 0.0]'),
#  Text(0.823960880195599, 0.13636363636363635, 'job_entrepreneur <= 0.5\ngini = 0.327\nsamples = 37\nvalue = [9.605, 37.121]'),
#  Text(0.8227383863080685, 0.045454545454545456, 'gini = 0.295\nsamples = 35\nvalue = [8.127, 37.121]'),
#  Text(0.8251833740831296, 0.045454545454545456, 'gini = 0.0\nsamples = 2\nvalue = [1.478, 0.0]'),
#  Text(0.8361858190709046, 0.3181818181818182, 'housing_yes <= 0.5\ngini = 0.415\nsamples = 350\nvalue = [120.431, 289.237]'),
#  Text(0.8312958435207825, 0.22727272727272727, 'age <= 80.0\ngini = 0.032\nsamples = 59\nvalue = [1.478, 88.163]'),
#  Text(0.8288508557457213, 0.13636363636363635, 'month_nov <= 0.5\ngini = 0.017\nsamples = 57\nvalue = [0.739, 86.616]'),
#  Text(0.8276283618581907, 0.045454545454545456, 'gini = 0.0\nsamples = 53\nvalue = [0.0, 81.976]'),
#  Text(0.8300733496332519, 0.045454545454545456, 'gini = 0.237\nsamples = 4\nvalue = [0.739, 4.64]'),
#  Text(0.8337408312958435, 0.13636363636363635, 'marital_married <= 0.5\ngini = 0.438\nsamples = 2\nvalue = [0.739, 1.547]'),
#  Text(0.8325183374083129, 0.045454545454545456, 'gini = 0.0\nsamples = 1\nvalue = [0.739, 0.0]'),
#  Text(0.8349633251833741, 0.045454545454545456, 'gini = 0.0\nsamples = 1\nvalue = [0.0, 1.547]'),
#  Text(0.8410757946210269, 0.22727272727272727, 'age <= 54.5\ngini = 0.467\nsamples = 291\nvalue = [118.953, 201.074]'),
#  Text(0.8386308068459658, 0.13636363636363635, 'duration <= 346.739\ngini = 0.445\nsamples = 258\nvalue = [97.527, 194.887]'),
#  Text(0.8374083129584352, 0.045454545454545456, 'gini = 0.471\nsamples = 53\nvalue = [30.292, 18.561]'),
#  Text(0.8398533007334963, 0.045454545454545456, 'gini = 0.4\nsamples = 205\nvalue = [67.235, 176.326]'),
#  Text(0.843520782396088, 0.13636363636363635, 'job_management <= 0.5\ngini = 0.348\nsamples = 33\nvalue = [21.426, 6.187]'),
#  Text(0.8422982885085575, 0.045454545454545456, 'gini = -0.0\nsamples = 23\nvalue = [16.993, 0.0]'),
#  Text(0.8447432762836186, 0.045454545454545456, 'gini = 0.486\nsamples = 10\nvalue = [4.433, 6.187]'),
#  Text(0.8726314180929096, 0.5909090909090909, 'housing_yes <= 0.5\ngini = 0.451\nsamples = 235\nvalue = [90.877, 173.233]'),
#  Text(0.8594132029339854, 0.5, 'age <= 54.5\ngini = 0.296\nsamples = 136\nvalue = [31.77, 143.845]'),
#  Text(0.8551344743276283, 0.4090909090909091, 'previous <= 8.0\ngini = 0.166\nsamples = 98\nvalue = [12.56, 125.284]'),
#  Text(0.8539119804400978, 0.3181818181818182, 'job_housemaid <= 0.5\ngini = 0.149\nsamples = 96\nvalue = [11.083, 125.284]'),
#  Text(0.8508557457212714, 0.22727272727272727, 'age <= 46.5\ngini = 0.134\nsamples = 93\nvalue = [9.605, 123.738]'),
#  Text(0.8484107579462102, 0.13636363636363635, 'default_yes <= 0.5\ngini = 0.025\nsamples = 38\nvalue = [0.739, 57.229]'),
#  Text(0.8471882640586798, 0.045454545454545456, 'gini = 0.0\nsamples = 37\nvalue = [0.0, 57.229]'),
#  Text(0.8496332518337408, 0.045454545454545456, 'gini = 0.0\nsamples = 1\nvalue = [0.739, 0.0]'),
#  Text(0.8533007334963325, 0.13636363636363635, 'job_retired <= 0.5\ngini = 0.208\nsamples = 55\nvalue = [8.866, 66.509]'),
#  Text(0.8520782396088019, 0.045454545454545456, 'gini = 0.18\nsamples = 53\nvalue = [7.388, 66.509]'),
#  Text(0.8545232273838631, 0.045454545454545456, 'gini = 0.0\nsamples = 2\nvalue = [1.478, 0.0]'),
#  Text(0.8569682151589242, 0.22727272727272727, 'campaign <= 5.0\ngini = 0.5\nsamples = 3\nvalue = [1.478, 1.547]'),
#  Text(0.8557457212713936, 0.13636363636363635, 'gini = 0.0\nsamples = 2\nvalue = [1.478, 0.0]'),
#  Text(0.8581907090464548, 0.13636363636363635, 'gini = 0.0\nsamples = 1\nvalue = [0.0, 1.547]'),
#  Text(0.8563569682151589, 0.3181818181818182, 'gini = -0.0\nsamples = 2\nvalue = [1.478, 0.0]'),
#  Text(0.8636919315403423, 0.4090909090909091, 'duration <= 349.338\ngini = 0.5\nsamples = 38\nvalue = [19.21, 18.561]'),
#  Text(0.8606356968215159, 0.3181818181818182, 'campaign <= 11.0\ngini = 0.269\nsamples = 12\nvalue = [8.127, 1.547]'),
#  Text(0.8594132029339854, 0.22727272727272727, 'gini = 0.0\nsamples = 11\nvalue = [8.127, 0.0]'),
#  Text(0.8618581907090465, 0.22727272727272727, 'gini = 0.0\nsamples = 1\nvalue = [0.0, 1.547]'),
#  Text(0.8667481662591687, 0.3181818181818182, 'marital_married <= 0.5\ngini = 0.478\nsamples = 26\nvalue = [11.083, 17.014]'),
#  Text(0.8643031784841075, 0.22727272727272727, 'job_housemaid <= 0.5\ngini = 0.159\nsamples = 6\nvalue = [0.739, 7.734]'),
#  Text(0.863080684596577, 0.13636363636363635, 'gini = 0.0\nsamples = 5\nvalue = [0.0, 7.734]'),
#  Text(0.8655256723716381, 0.13636363636363635, 'gini = 0.0\nsamples = 1\nvalue = [0.739, 0.0]'),
#  Text(0.8691931540342298, 0.22727272727272727, 'amount <= 2156.0\ngini = 0.499\nsamples = 20\nvalue = [10.344, 9.28]'),
#  Text(0.8679706601466992, 0.13636363636363635, 'amount <= -39.5\ngini = 0.428\nsamples = 17\nvalue = [10.344, 4.64]'),
#  Text(0.8667481662591687, 0.045454545454545456, 'gini = 0.0\nsamples = 2\nvalue = [0.0, 3.093]'),
#  Text(0.8691931540342298, 0.045454545454545456, 'gini = 0.226\nsamples = 15\nvalue = [10.344, 1.547]'),
#  Text(0.8704156479217604, 0.13636363636363635, 'gini = -0.0\nsamples = 3\nvalue = [0.0, 4.64]'),
#  Text(0.8858496332518337, 0.5, 'duration <= 391.366\ngini = 0.444\nsamples = 99\nvalue = [59.107, 29.388]'),
#  Text(0.8792787286063569, 0.4090909090909091, 'amount <= 0.5\ngini = 0.357\nsamples = 79\nvalue = [50.98, 15.467]'),
#  Text(0.8753056234718827, 0.3181818181818182, 'job_blue-collar <= 0.5\ngini = 0.493\nsamples = 22\nvalue = [11.821, 9.28]'),
#  Text(0.8740831295843521, 0.22727272727272727, 'campaign <= 6.5\ngini = 0.486\nsamples = 15\nvalue = [6.65, 9.28]'),
#  Text(0.8728606356968215, 0.13636363636363635, 'amount <= -60.5\ngini = 0.484\nsamples = 12\nvalue = [6.65, 4.64]'),
#  Text(0.871638141809291, 0.045454545454545456, 'gini = -0.0\nsamples = 7\nvalue = [5.172, 0.0]'),
#  Text(0.8740831295843521, 0.045454545454545456, 'gini = 0.366\nsamples = 5\nvalue = [1.478, 4.64]'),
#  Text(0.8753056234718827, 0.13636363636363635, 'gini = 0.0\nsamples = 3\nvalue = [0.0, 4.64]'),
#  Text(0.8765281173594132, 0.22727272727272727, 'gini = -0.0\nsamples = 7\nvalue = [5.172, 0.0]'),
#  Text(0.8832518337408313, 0.3181818181818182, 'campaign <= 3.5\ngini = 0.236\nsamples = 57\nvalue = [39.159, 6.187]'),
#  Text(0.8801955990220048, 0.22727272727272727, 'amount <= 746.5\ngini = 0.442\nsamples = 21\nvalue = [12.56, 6.187]'),
#  Text(0.8777506112469438, 0.13636363636363635, 'amount <= 21.5\ngini = 0.253\nsamples = 13\nvalue = [8.866, 1.547]'),
#  Text(0.8765281173594132, 0.045454545454545456, 'gini = 0.5\nsamples = 3\nvalue = [1.478, 1.547]'),
#  Text(0.8789731051344744, 0.045454545454545456, 'gini = 0.0\nsamples = 10\nvalue = [7.388, 0.0]'),
#  Text(0.882640586797066, 0.13636363636363635, 'amount <= 1339.0\ngini = 0.494\nsamples = 8\nvalue = [3.694, 4.64]'),
#  Text(0.8814180929095354, 0.045454545454545456, 'gini = 0.237\nsamples = 4\nvalue = [0.739, 4.64]'),
#  Text(0.8838630806845966, 0.045454545454545456, 'gini = 0.0\nsamples = 4\nvalue = [2.955, 0.0]'),
#  Text(0.8863080684596577, 0.22727272727272727, 'job_services <= 0.5\ngini = 0.0\nsamples = 36\nvalue = [26.598, 0.0]'),
#  Text(0.8850855745721271, 0.13636363636363635, 'gini = 0.0\nsamples = 31\nvalue = [22.904, 0.0]'),
#  Text(0.8875305623471883, 0.13636363636363635, 'gini = 0.0\nsamples = 5\nvalue = [3.694, 0.0]'),
#  Text(0.8924205378973105, 0.4090909090909091, 'marital_married <= 0.5\ngini = 0.465\nsamples = 20\nvalue = [8.127, 13.92]'),
#  Text(0.8899755501222494, 0.3181818181818182, 'duration <= 396.843\ngini = 0.451\nsamples = 10\nvalue = [5.911, 3.093]'),
#  Text(0.8887530562347188, 0.22727272727272727, 'gini = -0.0\nsamples = 6\nvalue = [4.433, 0.0]'),
#  Text(0.89119804400978, 0.22727272727272727, 'job_blue-collar <= 0.5\ngini = 0.438\nsamples = 4\nvalue = [1.478, 3.093]'),
#  Text(0.8899755501222494, 0.13636363636363635, 'gini = 0.0\nsamples = 2\nvalue = [0.0, 3.093]'),
#  Text(0.8924205378973105, 0.13636363636363635, 'gini = 0.0\nsamples = 2\nvalue = [1.478, 0.0]'),
#  Text(0.8948655256723717, 0.3181818181818182, 'amount <= 532.5\ngini = 0.282\nsamples = 10\nvalue = [2.217, 10.827]'),
#  Text(0.8936430317848411, 0.22727272727272727, 'gini = 0.0\nsamples = 6\nvalue = [0.0, 9.28]'),
#  Text(0.8960880195599022, 0.22727272727272727, 'age <= 30.0\ngini = 0.484\nsamples = 4\nvalue = [2.217, 1.547]'),
#  Text(0.8948655256723717, 0.13636363636363635, 'gini = 0.0\nsamples = 1\nvalue = [0.0, 1.547]'),
#  Text(0.8973105134474327, 0.13636363636363635, 'age <= 34.0\ngini = 0.0\nsamples = 3\nvalue = [2.217, 0.0]'),
#  Text(0.8960880195599022, 0.045454545454545456, 'gini = 0.0\nsamples = 1\nvalue = [0.739, 0.0]'),
#  Text(0.8985330073349633, 0.045454545454545456, 'gini = 0.0\nsamples = 2\nvalue = [1.478, 0.0]'),
#  Text(0.9469743276283619, 0.6818181818181818, 'loan_yes <= 0.5\ngini = 0.167\nsamples = 975\nvalue = [126.342, 1243.564]'),
#  Text(0.9210727383863081, 0.5909090909090909, 'age <= 49.5\ngini = 0.111\nsamples = 430\nvalue = [36.942, 587.754]'),
#  Text(0.914119804400978, 0.5, 'previous <= 15.5\ngini = 0.046\nsamples = 230\nvalue = [8.127, 338.732]'),
#  Text(0.9101466992665037, 0.4090909090909091, 'month_feb <= 0.5\ngini = 0.038\nsamples = 225\nvalue = [6.65, 334.092]'),
#  Text(0.9058679706601467, 0.3181818181818182, 'amount <= 17011.0\ngini = 0.028\nsamples = 207\nvalue = [4.433, 310.891]'),
#  Text(0.9034229828850856, 0.22727272727272727, 'duration <= 420.437\ngini = 0.023\nsamples = 204\nvalue = [3.694, 307.798]'),
#  Text(0.902200488997555, 0.13636363636363635, 'duration <= 420.383\ngini = 0.045\nsamples = 106\nvalue = [3.694, 156.219]'),
#  Text(0.9009779951100244, 0.045454545454545456, 'gini = 0.036\nsamples = 105\nvalue = [2.955, 156.219]'),
#  Text(0.9034229828850856, 0.045454545454545456, 'gini = -0.0\nsamples = 1\nvalue = [0.739, 0.0]'),
#  Text(0.9046454767726161, 0.13636363636363635, 'gini = -0.0\nsamples = 98\nvalue = [0.0, 151.579]'),
#  Text(0.9083129584352079, 0.22727272727272727, 'amount <= 20227.0\ngini = 0.311\nsamples = 3\nvalue = [0.739, 3.093]'),
#  Text(0.9070904645476773, 0.13636363636363635, 'gini = 0.0\nsamples = 1\nvalue = [0.739, 0.0]'),
#  Text(0.9095354523227384, 0.13636363636363635, 'gini = 0.0\nsamples = 2\nvalue = [0.0, 3.093]'),
#  Text(0.9144254278728606, 0.3181818181818182, 'job_services <= 0.5\ngini = 0.159\nsamples = 18\nvalue = [2.217, 23.201]'),
#  Text(0.91320293398533, 0.22727272727272727, 'amount <= -95.5\ngini = 0.113\nsamples = 17\nvalue = [1.478, 23.201]'),
#  Text(0.9119804400977995, 0.13636363636363635, 'gini = 0.0\nsamples = 1\nvalue = [0.739, 0.0]'),
#  Text(0.9144254278728606, 0.13636363636363635, 'job_technician <= 0.5\ngini = 0.06\nsamples = 16\nvalue = [0.739, 23.201]'),
#  Text(0.91320293398533, 0.045454545454545456, 'gini = 0.0\nsamples = 14\nvalue = [0.0, 21.654]'),
#  Text(0.9156479217603912, 0.045454545454545456, 'gini = 0.438\nsamples = 2\nvalue = [0.739, 1.547]'),
#  Text(0.9156479217603912, 0.22727272727272727, 'gini = -0.0\nsamples = 1\nvalue = [0.739, 0.0]'),
#  Text(0.9180929095354523, 0.4090909090909091, 'campaign <= 5.5\ngini = 0.366\nsamples = 5\nvalue = [1.478, 4.64]'),
#  Text(0.9168704156479217, 0.3181818181818182, 'gini = 0.0\nsamples = 3\nvalue = [0.0, 4.64]'),
#  Text(0.9193154034229829, 0.3181818181818182, 'gini = 0.0\nsamples = 2\nvalue = [1.478, 0.0]'),
#  Text(0.9280256723716381, 0.5, 'duration <= 403.374\ngini = 0.186\nsamples = 200\nvalue = [28.815, 249.022]'),
#  Text(0.9229828850855746, 0.4090909090909091, 'month_jan <= 0.5\ngini = 0.384\nsamples = 7\nvalue = [4.433, 1.547]'),
#  Text(0.921760391198044, 0.3181818181818182, 'previous <= 3.5\ngini = 0.0\nsamples = 6\nvalue = [4.433, 0.0]'),
#  Text(0.9205378973105135, 0.22727272727272727, 'gini = 0.0\nsamples = 5\nvalue = [3.694, 0.0]'),
#  Text(0.9229828850855746, 0.22727272727272727, 'gini = 0.0\nsamples = 1\nvalue = [0.739, 0.0]'),
#  Text(0.9242053789731052, 0.3181818181818182, 'gini = -0.0\nsamples = 1\nvalue = [0.0, 1.547]'),
#  Text(0.9330684596577017, 0.4090909090909091, 'duration <= 413.699\ngini = 0.163\nsamples = 193\nvalue = [24.382, 247.475]'),
#  Text(0.9278728606356969, 0.3181818181818182, 'amount <= 0.5\ngini = 0.311\nsamples = 33\nvalue = [8.127, 34.028]'),
#  Text(0.9254278728606357, 0.22727272727272727, 'age <= 59.0\ngini = 0.384\nsamples = 7\nvalue = [4.433, 1.547]'),
#  Text(0.9242053789731052, 0.13636363636363635, 'gini = -0.0\nsamples = 6\nvalue = [4.433, 0.0]'),
#  Text(0.9266503667481663, 0.13636363636363635, 'gini = 0.0\nsamples = 1\nvalue = [0.0, 1.547]'),
#  Text(0.9303178484107579, 0.22727272727272727, 'duration <= 413.493\ngini = 0.183\nsamples = 26\nvalue = [3.694, 32.481]'),
#  Text(0.9290953545232273, 0.13636363636363635, 'age <= 56.5\ngini = 0.153\nsamples = 25\nvalue = [2.955, 32.481]'),
#  Text(0.9278728606356969, 0.045454545454545456, 'gini = 0.053\nsamples = 18\nvalue = [0.739, 26.294]'),
#  Text(0.9303178484107579, 0.045454545454545456, 'gini = 0.388\nsamples = 7\nvalue = [2.217, 6.187]'),
#  Text(0.9315403422982885, 0.13636363636363635, 'gini = 0.0\nsamples = 1\nvalue = [0.739, 0.0]'),
#  Text(0.9382640586797066, 0.3181818181818182, 'amount <= -126.0\ngini = 0.132\nsamples = 160\nvalue = [16.255, 213.448]'),
#  Text(0.9352078239608802, 0.22727272727272727, 'duration <= 472.627\ngini = 0.388\nsamples = 7\nvalue = [2.217, 6.187]'),
#  Text(0.9339853300733496, 0.13636363636363635, 'contact_sending _document <= 0.5\ngini = 0.311\nsamples = 6\nvalue = [1.478, 6.187]'),
#  Text(0.9327628361858191, 0.045454545454545456, 'gini = 0.0\nsamples = 3\nvalue = [0.0, 4.64]'),
#  Text(0.9352078239608802, 0.045454545454545456, 'gini = 0.5\nsamples = 3\nvalue = [1.478, 1.547]'),
#  Text(0.9364303178484108, 0.13636363636363635, 'gini = 0.0\nsamples = 1\nvalue = [0.739, 0.0]'),
#  Text(0.941320293398533, 0.22727272727272727, 'previous <= 1.5\ngini = 0.119\nsamples = 153\nvalue = [14.038, 207.261]'),
#  Text(0.9388753056234719, 0.13636363636363635, 'campaign <= 3.5\ngini = 0.09\nsamples = 128\nvalue = [8.866, 179.42]'),
#  Text(0.9376528117359413, 0.045454545454545456, 'gini = 0.156\nsamples = 55\nvalue = [6.65, 71.149]'),
#  Text(0.9400977995110025, 0.045454545454545456, 'gini = 0.039\nsamples = 73\nvalue = [2.217, 108.271]'),
#  Text(0.9437652811735942, 0.13636363636363635, 'amount <= 4390.5\ngini = 0.264\nsamples = 25\nvalue = [5.172, 27.841]'),
#  Text(0.9425427872860636, 0.045454545454545456, 'gini = 0.207\nsamples = 23\nvalue = [3.694, 27.841]'),
#  Text(0.9449877750611247, 0.045454545454545456, 'gini = 0.0\nsamples = 2\nvalue = [1.478, 0.0]'),
#  Text(0.9728759168704156, 0.5909090909090909, 'duration <= 427.25\ngini = 0.211\nsamples = 545\nvalue = [89.4, 655.81]'),
#  Text(0.964242053789731, 0.5, 'duration <= 424.534\ngini = 0.415\nsamples = 73\nvalue = [25.121, 60.322]'),
#  Text(0.9602689486552567, 0.4090909090909091, 'default_yes <= 0.5\ngini = 0.378\nsamples = 65\nvalue = [19.949, 58.775]'),
#  Text(0.9559902200488998, 0.3181818181818182, 'age <= 33.5\ngini = 0.356\nsamples = 62\nvalue = [17.732, 58.775]'),
#  Text(0.9511002444987775, 0.22727272727272727, 'job_blue-collar <= 0.5\ngini = 0.159\nsamples = 24\nvalue = [2.955, 30.934]'),
#  Text(0.9486552567237164, 0.13636363636363635, 'month_may <= 0.5\ngini = 0.0\nsamples = 18\nvalue = [0.0, 27.841]'),
#  Text(0.9474327628361858, 0.045454545454545456, 'gini = 0.0\nsamples = 11\nvalue = [0.0, 17.014]'),
#  Text(0.9498777506112469, 0.045454545454545456, 'gini = 0.0\nsamples = 7\nvalue = [0.0, 10.827]'),
#  Text(0.9535452322738386, 0.13636363636363635, 'previous <= 0.5\ngini = 0.5\nsamples = 6\nvalue = [2.955, 3.093]'),
#  Text(0.9523227383863081, 0.045454545454545456, 'gini = 0.311\nsamples = 3\nvalue = [0.739, 3.093]'),
#  ...]
